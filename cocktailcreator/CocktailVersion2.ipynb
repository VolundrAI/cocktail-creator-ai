# %%
import pandas as pd
import plotly.express as px
import tensorflow as tf
import numpy as np
from tensorflow.keras.layers import Input, Dense, LSTM, Dropout, TextVectorization, Embedding
from tensorflow.keras.models import Model

from sklearn.preprocessing import LabelEncoder

from typing import List, Tuple
from tqdm import tqdm

# %%
def data_processing(cocktail_data_path: str, recipe_data_path: str) -> Tuple[pd.DataFrame, LabelEncoder, LabelEncoder]:
    """
    Read the input data, and transform into the structure needed for training a model
    
    Inputs:
        data_path:
            A string path to the input Mr Boston Cocktail Dataset
        
    Outputs:
        data:
            A pandas dataframe with all of the needed columns for training
        ingredient_encoder:
            A label encoder to transform ingredient names to numbers and back
        measurement_encoder:
            A label encoder to transform measurement amounts to numbers and back
    """
    
    cocktail_df = pd.read_csv(cocktail_data_path)
    
    cocktail_ingredients = pd.concat([cocktail_df["ingredient-1"], cocktail_df["ingredient-2"], cocktail_df["ingredient-3"], cocktail_df["ingredient-4"], cocktail_df["ingredient-5"], cocktail_df["ingredient-6"]]).unique()

    ingredient_encoder = LabelEncoder()
    ingredient_encoder.fit(ingredients)
    
    df["ingredient-1"] = ingredient_encoder.transform(df["ingredient-1"])
    df["ingredient-2"] = ingredient_encoder.transform(df["ingredient-2"])
    df["ingredient-3"] = ingredient_encoder.transform(df["ingredient-3"])
    df["ingredient-4"] = ingredient_encoder.transform(df["ingredient-4"])
    df["ingredient-5"] = ingredient_encoder.transform(df["ingredient-5"])
    df["ingredient-6"] = ingredient_encoder.transform(df["ingredient-6"])
    
    measurements = pd.concat([df["measurement-1"], df["measurement-2"], df["measurement-3"], df["measurement-4"], df["measurement-5"], df["measurement-6"]]).unique()

    measurement_encoder = LabelEncoder()
    measurement_encoder.fit(measurements)
    
    df["measurement-1"] = measurement_encoder.transform(df["measurement-1"])
    df["measurement-2"] = measurement_encoder.transform(df["measurement-2"])
    df["measurement-3"] = measurement_encoder.transform(df["measurement-3"])
    df["measurement-4"] = measurement_encoder.transform(df["measurement-4"])
    df["measurement-5"] = measurement_encoder.transform(df["measurement-5"])
    df["measurement-6"] = measurement_encoder.transform(df["measurement-6"])
    
    pieces = []
    pieces.append(df[["name"]])

    for i in range(6):
        temp = pd.DataFrame(data=tf.keras.utils.to_categorical(df[f"ingredient-{i+1}"]), columns=[f"I{i+1} - {c}" for c in ingredient_encoder.classes_])
        pieces.append(temp)

        temp = pd.DataFrame(data=tf.keras.utils.to_categorical(df[f"measurement-{i+1}"]), columns=[f"M{i+1} - {c}" for c in measurement_encoder.classes_])
        pieces.append(temp)

    data = pd.concat(pieces, axis=1)
    
    return data, ingredient_encoder, measurement_encoder

# %%
def prepare_model(data: pd.DataFrame, ingredient_encoder, measurement_encoder) -> Model:
    """
    
    """
    
    textvec = TextVectorization(
        max_tokens=20000,
        output_sequence_length=5,
        pad_to_max_tokens=True
    )

    ##TODO:
    ##Instead of using the names to adapt, use a more general text source
    extra_vocab = list(pd.read_csv("RAW_recipes.csv")["description"])
    name_vocab = list(data["name"])
    textvec.adapt(name_vocab + extra_vocab)

    voc = textvec.get_vocabulary()
    print(f"Found {len(voc)} different words!")
    word_index = dict(zip(voc, range(len(voc))))
    
    path_to_glove_file = "glove.6B.300d.txt"

    embeddings_index = {}
    with open(path_to_glove_file, encoding="utf8") as f:
        for line in f:
            word, coefs = line.split(maxsplit=1)
            coefs = np.fromstring(coefs, "f", sep=" ")
            embeddings_index[word] = coefs
    
    num_tokens = len(voc) + 2
    embedding_dim = 300
    hits = 0
    misses = 0

    # Prepare embedding matrix
    embedding_matrix = np.zeros((num_tokens, embedding_dim))
    for word, i in word_index.items():
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None:
            # Words not found in embedding index will be all-zeros.
            # This includes the representation for "padding" and "OOV"
            embedding_matrix[i] = embedding_vector
            hits += 1
        else:
            misses += 1
    
    encoder_inputs = Input(shape=(1,), dtype=tf.string)

    e = textvec(encoder_inputs)

    e = Embedding(
        num_tokens,
        embedding_dim,
        embeddings_initializer=tf.keras.initializers.Constant(embedding_matrix),
        trainable=False,
    )(e)

    encoder_outputs = LSTM(128)(e)

    d = Dense(64)(encoder_outputs)
    d = Dropout(0.25)(d)
    d = Dense(64)(d)
    d = Dropout(0.25)(d)

    i1 = Dense(len(ingredient_encoder.classes_), activation="sigmoid", name="i1_output")(d)
    i2 = Dense(len(ingredient_encoder.classes_), activation="sigmoid", name="i2_output")(d)
    i3 = Dense(len(ingredient_encoder.classes_), activation="sigmoid", name="i3_output")(d)
    i4 = Dense(len(ingredient_encoder.classes_), activation="sigmoid", name="i4_output")(d)
    i5 = Dense(len(ingredient_encoder.classes_), activation="sigmoid", name="i5_output")(d)
    i6 = Dense(len(ingredient_encoder.classes_), activation="sigmoid", name="i6_output")(d)

    m1 = Dense(len(measurement_encoder.classes_), activation="sigmoid", name="m1_output")(d)
    m2 = Dense(len(measurement_encoder.classes_), activation="sigmoid", name="m2_output")(d)
    m3 = Dense(len(measurement_encoder.classes_), activation="sigmoid", name="m3_output")(d)
    m4 = Dense(len(measurement_encoder.classes_), activation="sigmoid", name="m4_output")(d)
    m5 = Dense(len(measurement_encoder.classes_), activation="sigmoid", name="m5_output")(d)
    m6 = Dense(len(measurement_encoder.classes_), activation="sigmoid", name="m6_output")(d)

    decoder_outputs = [i1, m1, i2, m2, i3, m3, i4, m4, i5, m5, i6, m6]
    model = Model(encoder_inputs, decoder_outputs)
        
    losses = {
        "i1_output":"categorical_crossentropy",
        "i2_output":"categorical_crossentropy",
        "i3_output":"categorical_crossentropy",
        "i4_output":"categorical_crossentropy",
        "i5_output":"categorical_crossentropy",
        "i6_output":"categorical_crossentropy",
        "m1_output":"categorical_crossentropy",
        "m2_output":"categorical_crossentropy",
        "m3_output":"categorical_crossentropy",
        "m4_output":"categorical_crossentropy",
        "m5_output":"categorical_crossentropy",
        "m6_output":"categorical_crossentropy",
    }

    optimizer='adam'
    metrics = {
        "i1_output":tf.metrics.CategoricalAccuracy(name='acc'),
        "i2_output":tf.metrics.CategoricalAccuracy(name='acc'),
        "i3_output":tf.metrics.CategoricalAccuracy(name='acc'),
        "i4_output":tf.metrics.CategoricalAccuracy(name='acc'),
        "i5_output":tf.metrics.CategoricalAccuracy(name='acc'),
        "i6_output":tf.metrics.CategoricalAccuracy(name='acc'),
        "m1_output":tf.metrics.CategoricalAccuracy(name='acc'),
        "m2_output":tf.metrics.CategoricalAccuracy(name='acc'),
        "m3_output":tf.metrics.CategoricalAccuracy(name='acc'),
        "m4_output":tf.metrics.CategoricalAccuracy(name='acc'),
        "m5_output":tf.metrics.CategoricalAccuracy(name='acc'),
        "m6_output":tf.metrics.CategoricalAccuracy(name='acc'),
    }

    model.compile(loss=losses, metrics=metrics, optimizer=optimizer)
    
    return model

# %%
def fit_model(model, data, ingredient_encoder, measurement_encoder, epochs: int = 100) -> None:
    """
    
    """
    
    X = data[["name"]].values

    Ys = {}

    for i in range(6):
        temp = data[[col for col in data.columns if f"I{i+1} - " in col]]
        Ys[f"i{i+1}_output"] = temp.values
        if temp.values.shape[1] != len(ingredient_encoder.classes_):
            raise RuntimeError(f"Too many columns pulled! Problem on I{i+1}")

        temp = data[[col for col in data.columns if f"M{i+1} - " in col]]
        Ys[f"m{i+1}_output"] = temp.values
        if temp.values.shape[1] != len(measurement_encoder.classes_):
            raise RuntimeError(f"Too many columns pulled! Problem on I{i+1}")

    model.fit(X, Ys, epochs=epochs, verbose=1)

# %%
def transform_str2list(input_string) -> List[str]:
    """
    Takes a string that contains a list like: "[1, 2, 3]" and turns it
    into a list of strings like: ["1", "2", "3"]
    """
    
    clean = input_string[1:-1]
    pieces = clean.split(",")
    
    output_list = [piece.strip().lower().replace("\'", "").replace('"', "") for piece in pieces]
    
    return output_list

# %%
def create_recipe(name: str, model: Model, ingredient_encoder: LabelEncoder, measurement_encoder: LabelEncoder) -> List[str]:
    """
    
    """
    
    predicted_ingredients = model.predict([name])
    
    recipe = []
    for i in range(6):
        ingredient = predicted_ingredients[2*i]
        measurement = predicted_ingredients[2*i + 1]
        
        ingredient = np.argmax(ingredient)
        measurement = np.argmax(measurement)
        
        ingredient = ingredient_encoder.classes_[ingredient]
        measurement = measurement_encoder.classes_[measurement]
        
        if str(ingredient).strip().lower() == "nan":
            continue
        else:
            recipe.append(f"{measurement} of {ingredient}")
    
    return recipe

# %%
#data, ingredient_encoder, measurement_encoder = data_processing("mr-boston-flattened.csv")
#model = prepare_model(data, ingredient_encoder, measurement_encoder)
#fit_model(model, data, ingredient_encoder, measurement_encoder)

# %%
#recipe = create_recipe("Tomato Soup", model, ingredient_encoder, measurement_encoder)
#print(recipe)

# %%
recipe_df = pd.read_csv("Data/RAW_recipes.csv")

recipe_ingredients = set()

for ingredient_list in tqdm(recipe_df["ingredients"]):
    temp_set = set(transform_str2list(ingredient_list))
    recipe_ingredients = recipe_ingredients.union(temp_set)

recipe_ingredients = sorted(list(recipe_ingredients))
recipe_ingredients = [i.replace("\'", "").replace('"', "") for i in recipe_ingredients]
recipe_ingredients
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 231637/231637 [00:48<00:00, 4820.05it/s]
# ['adolphs meat tenderizer',
#  'annies goddess dressing',
#  'aunt janes krazy mixed up salt',
#  'bakers angel flake sweetened coconut',
#  'bakers germans chocolate',
#  'bakers joy',
#  'bakers semi-sweet baking chocolate',
#  'bakers semi-sweet chocolate',
#  'bakers special dry milk',
#  'bakers unsweetened chocolate square',
#  'bakers unsweetened chocolate squares',
#  'bakers yeast',
#  'bells seasoning',
#  'better n peanut butter spread',
#  'betty crockers hamburger helper',
#  'birds custard mix',
#  'birds eye custard',
#  'bobs red mill gluten-free all-purpose baking flour',
#  'boones farm strawberry hill wine',
#  'breakstones sour cream',
#  'brewers yeast',
#  'bushs red beans',
#  'butterfinger bbs',
#  'campbells cheddar cheese soup',
#  'campbells chicken gumbo soup',
#  'campbells chicken soup',
#  'campbells chunky beef with country vegetables soup',
#  'campbells chunky ready to serve vegetable soup',
#  'campbells condensed beef broth',
#  'campbells condensed chicken broth',
#  'campbells condensed cream of asparagus soup',
#  'campbells condensed cream of celery soup',
#  'campbells condensed tomato soup',
#  'campbells condensed vegetable soup',
#  'campbells cream of chicken soup',
#  'campbells cream of mushroom soup',
#  'campbells cream of shrimp soup',
#  'campbells creamy ranchero tomato soup',
#  'campbells french onion soup',
#  'campbells golden mushroom soup',
#  'campbells half-fat condensed cream of mushroom soup',
#  'campbells healthy request cream of broccoli soup',
#  'campbells nacho cheese soup',
#  'campbells ready to serve minestrone soup',
#  'campbells split pea soup',
#  'campbells tomato soup',
#  'campbells tomato zest soup',
#  'capn crunch cereal',
#  'captain morgans spiced rum',
#  'chi chis restaurante fiesta seasoning mix',
#  'chicken a la king',
#  'colemans dry mustard',
#  'confectioners coating',
#  'confectioners sugar',
#  'cookies n creme nuggets',
#  'cracklin oat bran cereal',
#  'dales steak seasoning',
#  'devils food cake mix with pudding',
#  'devils food cake mix',
#  'dried birds eye chile',
#  'dried birds eye chiles',
#  'durkees sauce',
#  'egglands best large egg',
#  'egglands best large eggs',
#  'emerils itailian essence',
#  'emerils kicked up horseradish mustard',
#  'emerils original essence',
#  'europes best carrots a la parisienne',
#  'europes best natures balance',
#  'europes best romanesco concerto frozen vegetables',
#  'europes best sunburst mangoes',
#  'evaporated goats milk',
#  'fakin bakin',
#  'farmers sausage',
#  'fisher chefs naturals sliced almonds',
#  'fisher chefs naturals slivered almonds',
#  'fisher chefs naturals walnut halves',
#  'fisher chefs naturals walnuts',
#  'fisher chefs naturals whole almonds',
#  'fleischmanns active dry yeast',
#  'fleischmanns margarine',
#  'franks red hot sauce',
#  'frenchs cheddar french fried onions',
#  'frenchs cheddar fried onions',
#  'frenchs french fried onions',
#  'frenchs mustard',
#  'frogs leg',
#  'frogs legs',
#  'gilbeys gin',
#  'goats cheese',
#  'goats milk',
#  'green birds eye chili',
#  'green birds eye chilies',
#  'gumbo file',
#  'hellmanns light mayonnaise',
#  'hellmanns mayonnaise',
#  'hersheys fudge topping',
#  'hersheys hugs chocolates',
#  'hersheys semi-sweet baking chocolate',
#  'hersheys semi-sweet chocolate chips',
#  'hersheys syrup',
#  'hunts diced tomatoes with basil',
#  'hunts diced tomatoes',
#  'hunts fire roasted diced tomatoes',
#  'hunts no-salt-added tomato paste',
#  'hunts tomato sauce with basil',
#  'hunts tomato sauce',
#  'hunts tomato sauce-no salt added',
#  'i cant believe its not butter fat free',
#  'i cant believe its not butter spread',
#  'i cant believe its not butter! original stick',
#  'i cant believe its not butter! spray original',
#  'i cant believe its not butter! spray',
#  'i cant believe its not butter',
#  'instant devils food pudding mix',
#  'instant devils food pudding',
#  'jack daniels sizzling smokehouse blend grilling sauce',
#  'jack daniels tennessee hickory mesquite grilling sauce',
#  'john salleys garlic-chipotle sauce',
#  'keens dry mustard',
#  'kelloggs all-bran cereal',
#  'kelloggs croutettes',
#  'kelloggs just right cereal',
#  'kikkomans teriyaki sauce',
#  'land o lakes butter',
#  'lawrys baja chipotle sauce with lime juice',
#  'lawrys mesquite marinade',
#  'lawrys seasoned pepper',
#  'lawrys seasoned salt',
#  'lawrys southwest marinade',
#  'lawrys teriyaki marinade',
#  'libbys canned pumpkin',
#  'lou prices cajun seasoning',
#  'm&m',
#  'm&ms peanut chocolate candies',
#  'm&ms peanut chocolate candy',
#  'm&ms plain chocolate candy',
#  'm&ms semi-sweet chocolate baking bits',
#  'm&ms',
#  'mac n cheese deluxe',
#  'makers mark bourbon whisky',
#  'mccormicks chicken stir-fry seasoning packet',
#  'mccormicks french herb roasting rub',
#  'mccormicks montreal brand steak seasoning',
#  'mccormicks montreal low-sodium steak seasoning',
#  'mccormicks salt-free all-purpose seasoning',
#  'mccormicks season all',
#  'mccormicks seasoning salt',
#  'meyers dark rum',
#  'mikes hard cranberry lemonade',
#  'miniature m&ms chocolate candies',
#  'morningstar farms better n burgers',
#  'mortons coarse kosher salt',
#  'mortons tender quick',
#  'motts cinnamon applesauce',
#  'mrs dashs extra spicy seasoning',
#  'mrs richardsons caramel topping',
#  'natures seasons',
#  'obrien frozen potatoes',
#  'obrien potatoes',
#  'paul newmans vinegar and oil dressing',
#  'peanut butter m&ms',
#  'perrusos spaghetti and meatballs sauce',
#  'pigs feet',
#  'pigs foot',
#  'pimms liqueur',
#  'planters fancy cashews',
#  'quaker ohs cereal',
#  'red birds eye chili',
#  'red birds eye chilies',
#  'reeses baking pieces',
#  'reeses peanut butter cups',
#  'reeses pieces',
#  'reeses puffs cereal',
#  'roses lime juice',
#  'sachet despices',
#  'semi-sweet hersheys chipits- small chocolate chip',
#  'sheeps milk cheese',
#  'simply potatoes obrien hash browns',
#  'smuckers black cherry flavored topping',
#  'smuckers caramel flavored topping',
#  'smuckers creamy natural peanut butter',
#  'smuckers hot dark chocolate microwaveable topping',
#  'smuckers natural creamy peanut butter',
#  'smuckers no sugar added orange spread',
#  'smuckers orchards finest coastal valley peach apricot preserves',
#  'smuckers orchards finest michigan red tart cherry preserves',
#  'smuckers orchards finest northwest triple berry preserves',
#  'smuckers orchards finest northwoods blueberry preserves',
#  'smuckers strawberry jelly',
#  'smuckers sugar-free strawberry jam',
#  'snackwells cinnamon snacks',
#  'snackwells fat-free wheat crackers',
#  'sugar-free reeses miniature peanut butter cups',
#  'sweet n low',
#  'sweetn low brown sugar substitute',
#  'taco bell home originals thick n chunky salsa',
#  'tony chacheres salt-free cajun spice',
#  'tony chacheres seasoning',
#  'trader joes 21 seasoning salute',
#  'trader joes creamy vegetable medley bisque',
#  'trappeys jalapenos',
#  'uncle bens brown and wild rice and mushrooms',
#  'uncle bens chicken-flavored wild rice',
#  'uncle bens converted brand rice',
#  'uncle bens ready rice',
#  'vernors soda',
#  'wylers chicken bouillon cubes',
#  'xxxx confectioners sugar',
#  'yves veggie ground round',
#  'zaatar spice mix',
#  'zatarains dry mix for coating meats',
#  'zatarains jambalaya mix',
#  'zatarains yellow rice',
#  '1% fat buttermilk',
#  '1% fat cottage cheese',
#  '1% low-fat chocolate milk',
#  '1% low-fat milk',
#  '10 bean soup mix',
#  '10 inch low-fat flour tortillas',
#  '10 pie crust',
#  '10% cream',
#  '10-inch  deep dish pie crust',
#  '10-inch baked pie shells',
#  '10-inch corn tortillas',
#  '10-inch flour tortilla',
#  '10-inch flour tortillas',
#  '10-inch pie shell',
#  '10-inch sun-dried tomato tortillas',
#  '10-inch unbaked deep-dish pie shell',
#  '10-inch whole wheat  tortillas',
#  '10-minute herb stuffing mix',
#  '10-minute success rice',
#  '100 proof vodka',
#  '100% bran',
#  '100-calorie honey maid cinnamon graham cracker crisps',
#  '100-calorie snack pack tapioca pudding',
#  '12-inch flour tortilla',
#  '12-inch flour tortillas',
#  '12-inch pizza crust',
#  '12-inch tortilla',
#  '13 bean soup mix',
#  '15 bean mix',
#  '15 bean soup mix',
#  '15 inch pizza crusts',
#  '15% cream',
#  '16 bean mix',
#  '18% table cream',
#  '2% buttermilk',
#  '2% cheddar cheese',
#  '2% evaporated milk',
#  '2% fat cottage cheese',
#  '2% large-curd cottage cheese',
#  '2% low-fat milk',
#  '2% mexican cheese blend',
#  '2% milk',
#  '2% mozzarella cheese',
#  '3 bean mix',
#  '3-cheese gourmet cheddar blend cheese',
#  '3-inch pie pastry tart shells',
#  '3-inch tart shells',
#  '35 % fresh cream',
#  '35% cream',
#  '4 grain bread flour',
#  '4% fat cottage cheese',
#  '5% fat ricotta cheese',
#  '5-inch pitas',
#  '6 cheese zesty mexican cheese blend',
#  '6 inch fat-free whole wheat pita bread',
#  '6-inch corn tortillas',
#  '6-inch flour tortillas',
#  '6-inch pitas',
#  '6-inch tortillas',
#  '6-inch whole wheat pitas',
#  '6-inch whole wheat tortilla',
#  '7 bean mix',
#  '7-inch flour tortillas',
#  '7-up soda',
#  '7-up',
#  '70% lean ground beef',
#  '8 inch pie shell',
#  '8-grain bread',
#  '8-inch 97% fat free flour tortillas',
#  '8-inch baked pie shell',
#  '8-inch double-crust pie shell',
#  '8-inch fat-free flour tortillas',
#  '8-inch flour tortillas',
#  '8-inch graham cracker crust',
#  '8-inch low-carb whole wheat tortilla',
#  '8-inch pre-baked crumb crust',
#  '8-inch ready-made graham cracker crust',
#  '8-inch unbaked pie shell',
#  '8-inch whole wheat flour tortillas',
#  '80% lean ground beef',
#  '85% lean ground beef',
#  '9 in. unbaked pastry shell',
#  '9 in. unbaked pastry shells',
#  '9 in.baked pastry shell',
#  '9 inch cake layers',
#  '9 inch chocolate cookie crumb crust',
#  '9 inch pie shell',
#  '9 baked deep dish pie crust',
#  '9 pastry crust with lattice top',
#  '9 pastry pie shells',
#  '9 pie shell',
#  '9 unbaked pie crust',
#  '9 unbaked pie shell',
#  '9 unbaked pie shells',
#  '9-grain bread',
#  '9-inch baked pie crust',
#  '9-inch baked pie crusts',
#  '9-inch chocolate pie crust',
#  '9-inch deep dish pie crust',
#  '9-inch deep dish pie crusts',
#  '9-inch double-crust pie shells',
#  '9-inch flour tortillas',
#  '9-inch graham cracker crust',
#  '9-inch graham cracker crusts',
#  '9-inch layers of chocolate cake',
#  '9-inch low-fat chocolate graham cracker crust',
#  '9-inch low-fat pie shell',
#  '9-inch oreo cookie pie crust',
#  '9-inch pie shell',
#  '9-inch pie shells',
#  '9-inch spinach tortillas',
#  '90% lean ground beef',
#  '92% lean ground beef',
#  '93% lean ground beef',
#  '94% lean ground beef',
#  '95% lean ground beef',
#  '96% lean ground beef',
#  '97% fat-free cooked ham',
#  '97% fat-free shaved leg ham',
#  '97% lean ground beef',
#  '98% fat free broccoli cheese soup',
#  '98% fat free condensed cream of celery soup',
#  '98% fat free cream of broccoli soup',
#  '98% fat-free cheddar cheese soup',
#  '98% fat-free condensed mushroom soup',
#  '98% fat-free cream of chicken soup',
#  '98% fat-free cream of mushroom soup',
#  '98% fat-free honey ham',
#  '98% lean ground beef',
#  '99% fat free orange flavored yogurt',
#  'a.1. original sauce',
#  'a.1. steak sauce',
#  'abalone steak',
#  'absinthe',
#  'absolut citron vodka',
#  'absolut kurant vodka',
#  'absolut mandarin vodka',
#  'absolut vodka',
#  'aburage',
#  'accent seasoning',
#  'aceto balsamico',
#  'achar',
#  'achiote oil',
#  'achiote paste cubes',
#  'achiote paste',
#  'achiote powder',
#  'achiote seeds',
#  'achiote',
#  'achute water',
#  'acid blend',
#  'acini di pepe pasta',
#  'ackee',
#  'acorn meal',
#  'acorn squash',
#  'acorn',
#  'acorns',
#  'active dry yeast',
#  'active starter',
#  'adobo sauce',
#  'adobo seasoning',
#  'advieh-e polo',
#  'advocaat',
#  'adzuki beans',
#  'african bird pepper',
#  'after dinner mints',
#  'agar',
#  'agar-agar flakes',
#  'agar-agar',
#  'agave nectar',
#  'agave syrup',
#  'agave',
#  'aged cheddar cheese',
#  'aged white cheddar cheese',
#  'aguardiente',
#  'agwa cocoa herbal liqueur',
#  'ahi fillets',
#  'ahi tuna steaks',
#  'ahi',
#  'ahmed brand vermicelli',
#  'aioli',
#  'aji bell peppers',
#  'aji panca chile',
#  'aji panca chilies',
#  'aji yellow paste',
#  'aji-no-moto',
#  'ajies dulces',
#  'ajinomoto',
#  'ajmoh seeds',
#  'ajvar',
#  'ajwain seed',
#  'ajwain',
#  'albacore tuna in water',
#  'albacore tuna',
#  'alcaparrado',
#  'alcohol',
#  'ale 8 soft drink',
#  'ale',
#  'aleppo pepper',
#  'alfalfa sprout',
#  'alfalfa sprouts',
#  'alfalfa',
#  'alfredo noodles mix',
#  'alfredo sauce mix',
#  'alfredo sauce with parmesan cheese',
#  'alfredo sauce',
#  'alize gold passion liqueur',
#  'alize red passion liqueur',
#  'all beef wieners',
#  'all bran extra fiber cereal',
#  'all purpose greek seasoning',
#  'all purpose wine yeast',
#  'all-bran cereal with raisins',
#  'all-bran cereal',
#  'all-fruit jam',
#  'all-fruit preserves',
#  'all-purpose flour',
#  'all-purpose white flour',
#  'allegro marinade',
#  'alligator meat',
#  'alligator sausage',
#  'alligator tail steaks',
#  'allspice berries',
#  'allspice berry',
#  'allspice',
#  'allwhites egg whites',
#  'almond bark',
#  'almond breeze non-dairy beverage',
#  'almond brickle chips',
#  'almond butter',
#  'almond cookie',
#  'almond cookies',
#  'almond emulsion',
#  'almond essence',
#  'almond extract',
#  'almond filling',
#  'almond flavored liqueur',
#  'almond flavoring',
#  'almond flour',
#  'almond granola',
#  'almond halve',
#  'almond halves',
#  'almond joy candy bars',
#  'almond liqueur',
#  'almond meal',
#  'almond milk',
#  'almond oil',
#  'almond paste',
#  'almond powder',
#  'almond syrup',
#  'almond toffee bits',
#  'almond-flavored liqueur',
#  'almond-stuffed green olives',
#  'almonds',
#  'aloe juice',
#  'aloe vera gel',
#  'alouette spinach artichoke spreadable cheese',
#  'alpha-bits cereal',
#  'alphabet pasta and vegetable soup',
#  'alphabet pasta',
#  'alphonso mangoes',
#  'alpine lace 97% reduced-fat cooked ham',
#  'alpine lace reduced-fat swiss cheese',
#  'alum',
#  'aluminum foil',
#  'amaranth flour',
#  'amaranth grain',
#  'amaranth',
#  'amaretti cookie crumbs',
#  'amaretti cookie',
#  'amaretti cookies',
#  'amaretti',
#  'amarettinis',
#  'amaretto cookies',
#  'amaretto cream liqueur',
#  'amaretto di saronno liqueur',
#  'amaretto flavored coffee creamer',
#  'amaretto liqueur',
#  'amaretto syrup',
#  'amaretto',
#  'amaretto-flavored coffee',
#  'amaretto-flavored nondairy liquid creamer',
#  'amarula cream liqueur',
#  'amber beer',
#  'amber rum',
#  'amchoor powder',
#  'amchur powder',
#  'amchur',
#  'american cheese spread',
#  'american cheese',
#  'amish batter',
#  'amish starter',
#  'ammonia',
#  'amul paneer',
#  'anaheim chili',
#  'anaheim chilies',
#  'anasazi beans',
#  'ancho chili puree',
#  'ancho chili',
#  'ancho chilies',
#  'anchovies packed in oil',
#  'anchovies',
#  'anchovy essence',
#  'anchovy fillet',
#  'anchovy fillets',
#  'anchovy packed in oil',
#  'anchovy paste',
#  'anchovy stock cube',
#  'anchovy',
#  'anchovy-stuffed olives',
#  'andes mint baking chips',
#  'andes mint parfait thins',
#  'andes mints candies',
#  'andouille chicken sausage',
#  'andouille sausage',
#  'andouille sausages',
#  'andouille turkey sausage',
#  'anejo cheese',
#  'angel flake coconut',
#  'angel food cake mix',
#  'angel food cake',
#  'angel hair pasta with herbs mix',
#  'angel hair pasta',
#  'angel hair with parmesan cheese pasta roni',
#  'angelica leaf',
#  'angelica leaves',
#  'angelica',
#  'angostura bitters',
#  'angostura low-sodium worcestershire sauce',
#  'angus steaks',
#  'animal crackers',
#  'anise extract',
#  'anise flavoring',
#  'anise oil',
#  'anise seed',
#  'anise seeds',
#  'anise',
#  'anise-flavored liqueur',
#  'anisette',
#  'anjou pear',
#  'anjou pears',
#  'annatto oil',
#  'annatto seeds',
#  'another sweetener',
#  'antelope cutlets',
#  'antelope steak',
#  'anthotiro',
#  'antipasto mix',
#  'any bottled italian dressing',
#  'any desired flavoring',
#  'any desired food coloring',
#  'appenzeller cheese',
#  'apple brandy',
#  'apple butter',
#  'apple chips',
#  'apple cider vinegar',
#  'apple cider',
#  'apple cinnamon cheerios',
#  'apple cinnamon granola cereal',
#  'apple cinnamon quick bread mix',
#  'apple crumble mix',
#  'apple fruit filling and topping',
#  'apple jack',
#  'apple jacks cereal',
#  'apple jelly',
#  'apple juice concentrate',
#  'apple juice',
#  'apple liqueur',
#  'apple peel',
#  'apple pie filling with cinnamon',
#  'apple pie filling',
#  'apple pie spice',
#  'apple pie',
#  'apple rings',
#  'apple schnapps',
#  'apple sweetened fortified soya milk',
#  'apple syrup',
#  'apple tart mix',
#  'apple vodka',
#  'apple yogurt',
#  'apple',
#  'apple-raspberry juice concentrate',
#  'apple-smoked bacon',
#  'applejack',
#  'apples for pie',
#  'apples for pies',
#  'apples in syrup',
#  'apples',
#  'applesauce',
#  'apricot baby food',
#  'apricot brandy',
#  'apricot conserve',
#  'apricot filling',
#  'apricot fruit spread',
#  'apricot gelatin',
#  'apricot halves in juice',
#  'apricot halves in light syrup',
#  'apricot halves',
#  'apricot jam',
#  'apricot jell-o',
#  'apricot juice',
#  'apricot liqueur',
#  'apricot marmalade',
#  'apricot nectar',
#  'apricot preserves',
#  'apricot puree',
#  'apricot syrup',
#  'apricot with tapioca baby food',
#  'apricot yoghurt',
#  'apricot',
#  'apricot-pineapple preserves',
#  'apricots in juice',
#  'apricots in light syrup',
#  'apricots in syrup',
#  'apricots',
#  'aquavit',
#  'arabic bread',
#  'arabic seven spice',
#  'arabic spices',
#  'arame seaweed',
#  'arbol chile',
#  'arbol chiles',
#  'arbol chili powder',
#  'arborio rice',
#  'arctic char',
#  'arepa flour',
#  'argan oil',
#  'arm roast',
#  'armagnac',
#  'aroma seasoning',
#  'aromatic bitters',
#  'arrack liqueur',
#  'arrowroot cookies',
#  'arrowroot',
#  'artichoke and garlic sausage',
#  'artichoke bottom',
#  'artichoke bottoms',
#  'artichoke dip',
#  'artichoke heart',
#  'artichoke hearts in brine',
#  'artichoke hearts packed in oil',
#  'artichoke hearts',
#  'artichoke pesto',
#  'artichoke quarters in water',
#  'artichoke',
#  'artichokes',
#  'artificial flower',
#  'artificial sweetener',
#  'artificial vanilla flavoring',
#  'artisan bread',
#  'arugula leaf',
#  'arugula leaves',
#  'arugula',
#  'asadero cheese',
#  'asafoetida powder',
#  'ascorbic acid',
#  'asiago 3-cheese blend',
#  'asiago caesar salad dressing',
#  'asiago cheese bagels',
#  'asiago cheese croutons',
#  'asiago cheese rolls',
#  'asiago cheese',
#  'asiago-parmesan cheese',
#  'asian chili peppers',
#  'asian chili sauce',
#  'asian noodles',
#  'asian pear',
#  'asian pears',
#  'asian rice flour',
#  'asian seasoning',
#  'asian-style dressing',
#  'asparagus spear',
#  'asparagus spears',
#  'asparagus tips',
#  'asparagus',
#  'assorted crudites',
#  'assorted fresh herb leaves',
#  'assorted fresh vegetable',
#  'assorted fresh vegetables',
#  'assorted herbs',
#  'asti spumante sparkling wine',
#  'astragalus root',
#  'atkins baking mix',
#  'au gratin potato mix',
#  'au gratin potatoes',
#  'au jus mix',
#  'au jus sauce',
#  'aubergine',
#  'aubergines',
#  'avgolemono sauce',
#  'avocado dip',
#  'avocado oil',
#  'avocado',
#  'avocados',
#  'azuki beans',
#  'b&m baked beans',
#  'baby apricots',
#  'baby artichoke',
#  'baby artichokes',
#  'baby arugula',
#  'baby asparagus',
#  'baby back rib rack',
#  'baby back rib racks',
#  'baby back ribs',
#  'baby banana puree',
#  'baby beef liver',
#  'baby beets',
#  'baby bella mushroom',
#  'baby bella mushrooms',
#  'baby bok choy',
#  'baby butter beans',
#  'baby calamari',
#  'baby carrots',
#  'baby chicken',
#  'baby chickens',
#  'baby clams',
#  'baby corn',
#  'baby dill pickle',
#  'baby dill pickles',
#  'baby dou miao',
#  'baby eggplant',
#  'baby eggplants',
#  'baby food',
#  'baby french beans',
#  'baby gourmet potato blend',
#  'baby green pea',
#  'baby green peas',
#  'baby greens',
#  'baby kai lan',
#  'baby leaf lettuce',
#  'baby leeks',
#  'baby lettuces',
#  'baby lima beans',
#  'baby marrows',
#  'baby mustard cress',
#  'baby octopus',
#  'baby onion',
#  'baby onions',
#  'baby oysters',
#  'baby peas',
#  'baby plums',
#  'baby portabella mushrooms',
#  'baby potatoes',
#  'baby red peppers',
#  'baby red potato',
#  'baby red potatoes',
#  'baby rocket',
#  'baby ruth candy bars',
#  'baby salad leaves',
#  'baby shrimp',
#  'baby spinach leaves',
#  'baby spinach',
#  'baby sweet corn cob',
#  'baby sweet corn cobs',
#  'baby swiss cheese',
#  'baby tomatoes',
#  'baby turnip',
#  'baby turnips',
#  'bacardi 151 rum',
#  'bacardi dark rum',
#  'bacardi fuzzy navel mix',
#  'bacardi light rum',
#  'bacardi limon',
#  'bacardi o rum',
#  'bacardi peach red rum',
#  'back bacon',
#  'back ribs',
#  'backfin crab meat',
#  'bacon bits',
#  'bacon cheddar cheese',
#  'bacon dip',
#  'bacon drippings',
#  'bacon fat',
#  'bacon grease',
#  'bacon piece',
#  'bacon pieces',
#  'bacon ranch dressing',
#  'bacon',
#  'bacos bacon bits',
#  'badam powder',
#  'badia complete seasoning',
#  'bagel chips',
#  'bagel',
#  'bagels',
#  'bagoong',
#  'baguette',
#  'baharat spice mix',
#  'baharat',
#  'baileys caramel irish cream',
#  'baileys irish cream',
#  'baileys mint chocolate irish cream liqueur',
#  'baileys original irish cream',
#  'baked beans in tomato sauce',
#  'baked beans with molasses',
#  'baked beans',
#  'baked cheese puffs',
#  'baked corn tortilla chips',
#  'baked potato chips',
#  'baked tofu',
#  'baking ammonia',
#  'baking apple',
#  'baking apples',
#  'baking chocolate squares',
#  'baking chocolate',
#  'baking cocoa',
#  'baking hen',
#  'baking hens',
#  'baking mix',
#  'baking potato',
#  'baking potatoes',
#  'baking powder biscuits',
#  'baking powder',
#  'baking sheet',
#  'baking soda',
#  'balkan style yogurt',
#  'ballard cornbread mix',
#  'balloons',
#  'baloney',
#  'balsamic dressing',
#  'balsamic glaze',
#  'balsamic syrup',
#  'balsamic vinaigrette',
#  'balsamic vinegar',
#  'bamba',
#  'bamboo leaves',
#  'bamboo shoot',
#  'bamboo shoots',
#  'bamboo skewer',
#  'bamboo skewers',
#  'banana baby food',
#  'banana blossom',
#  'banana bread mix',
#  'banana bread',
#  'banana cake mix',
#  'banana chips',
#  'banana cream instant pudding',
#  'banana cream pudding and pie filling mix',
#  'banana extract',
#  'banana flavoring',
#  'banana flower',
#  'banana flowers',
#  'banana granola',
#  'banana ice cream',
#  'banana instant pudding',
#  'banana ketchup',
#  'banana leaf',
#  'banana leaves',
#  'banana liqueur',
#  'banana milk',
#  'banana muffin mix',
#  'banana nut bread',
#  'banana nut cheerios',
#  'banana nut crunch cereal',
#  'banana nut muffin mix',
#  'banana pepper juice',
#  'banana pepper ring',
#  'banana pepper rings',
#  'banana pepper',
#  'banana peppers',
#  'banana pulp',
#  'banana rum',
#  'banana schnapps',
#  'banana squash',
#  'banana syrup',
#  'banana yogurt',
#  'banana',
#  'banana-blueberry yogurt',
#  'banana-flavor brandy',
#  'bananas',
#  'bangers',
#  'bangus',
#  'barbados molasses',
#  'barbecue baked beans',
#  'barbecue potato chips',
#  'barbecue sauce concentrate',
#  'barbecue sauce',
#  'barbecue seasoning',
#  'barbecue skewers',
#  'barbecue spice',
#  'barbecued beef',
#  'barbecued chicken',
#  'barbecued pork',
#  'barberries',
#  'barilla castellane',
#  'barilla lasagna',
#  'barilla linguine',
#  'barilla mushroom & garlic sauce',
#  'barilla sweet peppers & garlic sauce',
#  'barley flour',
#  'barley malt syrup',
#  'barley malt',
#  'barley miso',
#  'barley nugget cereal',
#  'barley pearls',
#  'barley rusks',
#  'barley',
#  'barramundi fillets',
#  'bartlett pear',
#  'bartlett pears',
#  'basa fillets',
#  'basic mayonnaise recipe',
#  'basic meatloaf',
#  'basic pizza dough',
#  'basil and parmesan tapenade',
#  'basil chiffonade',
#  'basil leaves',
#  'basil mayonnaise',
#  'basil oil',
#  'basil olive oil',
#  'basil pesto',
#  'basil seeds',
#  'basil sprig',
#  'basil sprigs',
#  'basil vinaigrette',
#  'basil',
#  'basmati rice pilaf',
#  'basmati rice',
#  'bass fillet',
#  'bass fillets',
#  'bath soap',
#  'batter frying mix',
#  'batter',
#  'bavarian smoked cheese',
#  'bavarian-style sweet sauerkraut',
#  'bay bugs',
#  'bay laurel powder',
#  'bay leaf powder',
#  'bay leaf',
#  'bay leaves',
#  'bay scallop',
#  'bay scallops',
#  'bay shrimp',
#  'bayou blast creole seasoning',
#  'bean curd',
#  'bean dip',
#  'bean flour',
#  'bean liquid',
#  'bean medley',
#  'bean paste',
#  'bean sauce',
#  'bean sprouts',
#  'bean stock',
#  'bean thread noodles',
#  'bean thread vermicelli',
#  'bean threads',
#  'bean with bacon soup',
#  'beans and carrots vegetable mix',
#  'beans in chili sauce',
#  'beans',
#  'bear meat',
#  'bear roast',
#  'bear shaped graham crackers',
#  'bear steak',
#  'bearnaise sauce mix',
#  'bearnaise sauce',
#  'beaten rice',
#  'beau monde seasoning',
#  'beau monde spice',
#  'beaufort cheese',
#  'beaujolais wine',
#  'becel margarine',
#  'becel oil',
#  'bechamel sauce',
#  'bee pollen',
#  'beef and onion soup mix',
#  'beef baby food',
#  'beef back ribs',
#  'beef bacon',
#  'beef base',
#  'beef blade roast',
#  'beef blade steak',
#  'beef bone',
#  'beef bones with marrow',
#  'beef bones',
#  'beef bouillon concentrate',
#  'beef bouillon cube',
#  'beef bouillon cubes',
#  'beef bouillon granules',
#  'beef bouillon paste',
#  'beef bouillon powder',
#  'beef bouillon',
#  'beef brains',
#  'beef brisket',
#  'beef broth',
#  'beef burgers',
#  'beef caps',
#  'beef cheek',
#  ...]

# %%
cocktail_df = pd.read_csv("Data/mr-boston-flattened.csv")
cocktail_ingredients = pd.concat([cocktail_df["ingredient-1"], cocktail_df["ingredient-2"], cocktail_df["ingredient-3"], cocktail_df["ingredient-4"], cocktail_df["ingredient-5"], cocktail_df["ingredient-6"]]).unique()
cocktail_ingredients = [str(i).strip().lower().replace(",", "") for i in cocktail_ingredients]
cocktail_ingredients
# Out:
# ['light rum',
#  'apple schnapps',
#  'juice of a lime',
#  'dark rum',
#  'bourbon whiskey',
#  'amaretto',
#  'scotch whiskey',
#  'bacardi rum',
#  'brandy',
#  'gin',
#  'sloe gin',
#  'sweet vermouth',
#  'tanqueray gin',
#  'lemon juice',
#  'straight rye whiskey',
#  'grenadine',
#  'green chartreuse',
#  'irish whiskey',
#  'dry vermouth',
#  'juice of a lemon',
#  'orange',
#  'absinthe',
#  'rye or bourbon whiskey',
#  'light vermouth',
#  'anisette',
#  'kummel',
#  'bourbon or rye whiskey',
#  'tennessee whiskey',
#  'vodka',
#  'grapefruit juice',
#  'fresh rosemary sprig',
#  'powdered sugar',
#  'wide spiral of lemon zest',
#  'lemon-flavored vodka',
#  'lime juice',
#  'blended scotch whiskey',
#  'apricot flavored brandy',
#  'bitters',
#  'juice of orange',
#  'orange bitters',
#  'blended scotch whiskey',
#  'white whiskey',
#  'dry gin',
#  'forbidden fruit',
#  'applejack',
#  'port',
#  'apple brandy',
#  'maraschino',
#  'coffee-flavored brandy',
#  'single-malt scotch whisky',
#  'hennessy v.s cognac',
#  'cherry-flavored brandy',
#  'creme de menthe (white)',
#  'creme de cacao (brown)',
#  'creme de cacao (white)',
#  'bourbon',
#  'springs mint',
#  'bourbon',
#  'pineapple juice',
#  'sake',
#  'amaretto di saronno',
#  'mr. boston gin',
#  'bourbon or rye whiskey',
#  'mandarine napoleon liqueur',
#  'lime wedge sweet chili powder',
#  'aquavit or vodka',
#  'fresh strawberries cut in halves',
#  'lemon wedge cinnamon sugar',
#  'mr. boston triple sec',
#  'georgia moon corn whiskey',
#  'orange-flavored vodka',
#  'fresh cilantro leaves',
#  'citrus-flavored vodka',
#  'dubonnet rouge',
#  'hot tea',
#  'old thompson blended whiskey',
#  'lemon wedge superfine sugar',
#  'absinthe or pastis',
#  'powdered sugar',
#  'vanilla-infused bourbon',
#  'cognac',
#  'bourbon whiskey',
#  'lemon wedge coarse salt',
#  'grapefruit-flavored vodka',
#  'for glass lemon wedge coarse salt',
#  'clementine or mandarin orange',
#  'strawberries cut into halves',
#  'canadian whisky',
#  'maraschino liqueur',
#  'egg',
#  'mint sprigs',
#  'mr. boston five star brandy',
#  'lemon wedge superfine sugar  long wide spiral of orange zest',
#  'smoky scotch whisky such as laphroaig',
#  'vanilla ice cream',
#  'straight rye whisky',
#  'cider',
#  'cynar',
#  'orange juice',
#  'vanilla liqueur',
#  'blended whiskey',
#  'raspberry yogurt',
#  'whole egg',
#  'danish cherry wine',
#  'cherry vodka',
#  'lime wedge superfine sugar',
#  'chilled stout',
#  'strega',
#  'hot black coffee',
#  'egg white',
#  'hot shot tropical fruit liqueur',
#  'strawberry schnapps',
#  'brown sugar cube such as demerara',
#  'cream sherry',
#  'nan',
#  'peach-flavored vodka',
#  'scotch',
#  'tequila',
#  'powdered sugar',
#  'dubonnet',
#  'chilled passion fruit juice',
#  'vanilla-flavored vodka',
#  'mint-flavored gin',
#  'fresh basil leaves',
#  'absinthe substitute',
#  'mr. boston vodka',
#  'black cherry-flavored vodka',
#  'calvados',
#  'red wine',
#  'cucumber slices chopped',
#  'rock and rye',
#  'aquavit',
#  'benedictine',
#  'lump of sugar',
#  'cucumber slices',
#  'apricot-flavored brandy',
#  'lime wedge pink sanding sugar',
#  'lime vodka',
#  'pisco',
#  'grape juice',
#  'lemon wedges',
#  'whole egg',
#  '100-proof vodka',
#  'yellow chartreuse',
#  'wine (port cream sherry claret burgundy or madeira)',
#  'peach slice skinned',
#  'splash triple sec',
#  'triple sec',
#  'dubonnet',
#  'bison grass vodka (zubrowka)',
#  'gold rum',
#  'egg yolk',
#  'medium eggs',
#  'peach-flavored brandy',
#  'ripe pear',
#  'peeled and chopped fresh ginger',
#  'brandy preferably spanish',
#  'cachaca',
#  'creme de cassis',
#  'fresh cherry tomatoes',
#  'white creme de cacao',
#  'thin peeled fresh ginger',
#  'dry sherry',
#  '17-year-old j. wray and nephew ltd. rum',
#  'applejack',
#  'aged rhum agricole',
#  'light or dark rum',
#  'anis',
#  'old mr. boston creme de menthe (white)',
#  'armagnac',
#  'old mr. boston blended whiskey',
#  'jamaica rum',
#  'red grapes',
#  'coconut rum',
#  'old mr. boston five star brandy',
#  'coconut-flavored rum',
#  'cachaca (brazilian rum)',
#  'elderflower liqueur',
#  'mint leaves',
#  'blanco tequila',
#  'lime wedges',
#  'old mr. boston anisette',
#  'lemon wedge celery salt',
#  'old mr. boston apricot flavored brandy',
#  'old mr. boston tequila',
#  'old mr. boston white creme de menthe',
#  'chilled rhine wine or sauterne',
#  'old mr. boston vodka',
#  'old mr. boston dry gin',
#  'raspberry-flavored vodka',
#  'strawberry chopped',
#  'desmond & duff scotch whisky',
#  'pear-flavored vodka',
#  'old mr. boston green creme de menthe',
#  'old mr. boston grape vodka',
#  'cucumber',
#  'lime wedge coarse salt',
#  'reposado blanco tequila',
#  'absinthe',
#  'orange peel',
#  'mr. boston creme de noyaux',
#  'gold tequila',
#  'old mr. boston rum',
#  'sweet cream',
#  'coarse salt',
#  'blueberries',
#  'lime wedge superfine sugar or coarse salt (optional)',
#  'smoky scotch whisky such as islay or skye',
#  'old mr. boston orange flavored gin',
#  'reposado tequila',
#  'cherry-flavored brandy superfine sugar',
#  'mezcal',
#  'old mr. boston sloe gin',
#  'mr. boston creme de menthe',
#  'old mr. boston kummel',
#  'dark rum preferably jamaican',
#  'fresh ginger',
#  'old mr. boston triple sec',
#  '151-proof rum',
#  'spiced rum',
#  'old mr. boston 100 proof vodka',
#  'creme de violette',
#  'each light rum gin vodka blanco tequila blue curacao',
#  "rose's lime juice",
#  'each dark rum light rum',
#  'anejo tequila',
#  'lemon wheel coarse salt',
#  'old kentucky tavern bourbon whiskey',
#  'blackberry-flavored brandy',
#  'campari',
#  'anejo tequila',
#  'lime wedges',
#  'orange juice',
#  'whole strawberry hulled',
#  'lime wedge coarse salt',
#  'lime juice coarse salt',
#  'fresh sage leaves',
#  'lime wedge superfine sugar',
#  'passion fruit syrup',
#  'cinnamon schnapps',
#  'cranberry juice',
#  'fresh lemon juice',
#  'creme de banana',
#  'fresh carrot juice',
#  'white creme de menthe',
#  'green creme de menthe',
#  'margarita mix',
#  'ginger ale or soda water',
#  'orgeat or almond syrup',
#  'half-and-half',
#  'pineapple',
#  'simple syrup',
#  'fresh lime juice',
#  'apple cider',
#  'fernet-branca',
#  'coffee liqueur',
#  'water',
#  'gin & ginger ale',
#  'grand marnier',
#  'juice of lemon or lime',
#  "pimm's no. 1 cup",
#  'pedro ximenez sherry',
#  'curacao',
#  'hard cider',
#  'club soda',
#  'strawberry liqueur',
#  'maple syrup (grade b or medium-amber)',
#  'tonic water',
#  'lillet blanc',
#  'apple juice',
#  'collins mix',
#  'kirschwasser',
#  'unsweetened grape juice',
#  'cold water',
#  'peach schnapps',
#  'coconut milk',
#  'roses lime juice',
#  'pear brandy',
#  'dark creme de cacao',
#  'angostura bitters',
#  'mango-flavored vodka',
#  'fresh grapefruit juice',
#  'orange juice',
#  'cherry heering',
#  'mountain dew',
#  'slice peeled fresh ginger',
#  'mint syrup',
#  'rose water',
#  'ginger liqueur',
#  'amontillado sherry',
#  'madeira',
#  'carbonated water',
#  'honey-currant syrup',
#  'tawny port',
#  'orange liqueur',
#  'coconut liqueur',
#  'pomegranate juice',
#  'mr. boston rum',
#  'orange curacao',
#  'tomato juice',
#  'rhubarb syrup',
#  'milk',
#  'light cream',
#  'raspberry ice cream',
#  'concord grape juice',
#  'clam juice',
#  'cola',
#  'sugar',
#  'chilled champagne',
#  'pineapple or grapefruit juice',
#  'amaro',
#  'cream sherry',
#  'worcestershire sauce',
#  'ginger syrup',
#  'irish cream liqueur',
#  'white port wine',
#  'gingerbread liqueur',
#  'lychee liqueur',
#  'limoncello',
#  'ginger ale',
#  'raspberry-flavored liqueur',
#  'old tom gin',
#  'boiling water',
#  'melon liqueur',
#  'each citrus-flavored vodka and orange-flavored vodka',
#  'hot apple cider',
#  'tonic',
#  'ginger beer',
#  'lime liqueur',
#  'fresh orange juice',
#  'lemon-lime soda',
#  'punt e mes',
#  'orange flavored gin',
#  'swedish punch',
#  'soda water',
#  'superfine sugar',
#  'vermouth',
#  'dried orange peel',
#  'creme de noyaux',
#  'sambuca',
#  'black raspberry liqueur',
#  'blue curacao',
#  'smoky scotch such as laphroaig',
#  'fresh mint leaves',
#  'maple syrup',
#  'cherry liqueur',
#  'creme de cacao',
#  'sweet sherry',
#  'demerara syrup',
#  'coffee-flavored liqueur',
#  'butterscotch schnapps',
#  'creole shrubb (rum-based orange liqueur)',
#  'fresh lemon or lime juice',
#  'lemon',
#  'cointreau or triple sec',
#  'fresh mint leaves',
#  'cold beef bouillon',
#  'lemonade',
#  'calvados apple brandy or applejack',
#  'carbonated water',
#  'white chocolate liqueur',
#  'chilled beer or ale',
#  'white grapes',
#  'cola',
#  'pineapple',
#  'old mr. boston white creme de cacao',
#  'bing cherries',
#  'minced ginger',
#  'fresh strawberries cut in half',
#  'rye whiskey',
#  'falernum',
#  'aperol',
#  'water',
#  'lump sugar',
#  'claret',
#  'cold brewed coffee',
#  'old mr. boston rock and rye',
#  'fresh white or ruby red grapefruit juice',
#  'grapefruit-flavored soda',
#  'palo cortado or oloroso sherry',
#  'old mr. boston wild cherry flavored brandy',
#  'each lillet blanc and lillet rouge',
#  'manzanilla sherry',
#  'blood orange liqueur',
#  'honey liqueur',
#  'whole strawberry',
#  'champagne',
#  'white curacao',
#  'lillet rouge',
#  'oloroso sherry',
#  'agave nectar',
#  'fresh cilantro sprigs',
#  'sweet sherry preferably pedro ximenez',
#  'apple slice',
#  'chilled champagne',
#  'lemon twist (optional)',
#  'ginger ale',
#  'milk or half-and-half',
#  'lemon or orange sherbet',
#  'soda water or ginger ale',
#  'chilled sparkling wine',
#  'aromatic bitters',
#  'heavy cream',
#  'lemon or lime wedge',
#  'creme de menthe',
#  'honey syrup',
#  'crushed pineapple',
#  'peach liqueur',
#  'lime wedge',
#  'mr. boston apricot flavored brandy',
#  'passion fruit juice',
#  'whipped cream',
#  'peach bitters',
#  'lemon twist',
#  'fresh orange juice and orange wheel',
#  'blackberry liqueur',
#  'canned coconut milk',
#  'fresh ruby red grapefruit juice',
#  'ramazzotti amaro',
#  'amer picon or torani amer',
#  'v8 cocktail juice',
#  'raspberry syrup',
#  'maraschino cherry',
#  'cold brewed green tea',
#  'lemon quarter-wheel',
#  'muscatel wine',
#  'dill pickle brine',
#  'sweet pickle brine',
#  'carbonated water',
#  'catsup',
#  'pepper and salt',
#  'cold brewed black tea preferably japanese',
#  'shaved ice',
#  'peach puree',
#  'amaro nonino',
#  'chile syrup',
#  'lemon',
#  'crema di limoncello',
#  'blended whiskey',
#  'galliano',
#  'lemon or lime juice',
#  'white rum',
#  'cinnamon sticks',
#  'red wine',
#  'black licorice stick',
#  'pastis',
#  'orange bitters (if desired)',
#  'each vodka tequila blanco triple sec',
#  'whole milk',
#  'each simple syrup light rum dark rum',
#  'white or dark creme de cacao',
#  'fresh apple cider',
#  'lime',
#  'ruby port',
#  'tomato catsup',
#  'each fresh lime juice jamaica rum grenadine',
#  'warm milk',
#  'tomato-clam juice',
#  'lime wheel',
#  'blood or navel orange half-wheel',
#  'black cherry juice',
#  'hot red pepper sauce',
#  'white curacao or triple sec',
#  'lemon twist',
#  'lemon slice',
#  'fresh celery juice',
#  'light sweet cream',
#  'tropical fruit schnapps',
#  'angostura bitters',
#  'creme yvette',
#  "vanilla syrup preferably b.a. reynold's",
#  'batavia arrack or light rum',
#  'creme de peche',
#  'bitters',
#  'fresh lime juice (reserve 1/2 lime shell for garnish)',
#  'allspice liqueur (pimento dram)',
#  'blood orange juice',
#  'cointreau triple sec',
#  'pear liqueur',
#  'becherovka (czech digestif)',
#  'peppermint schnapps',
#  'olive brine',
#  'old mr. boston triple sec',
#  'drambuie',
#  'old mr. boston imported rum',
#  'juice of a blood orange',
#  'old mr. boston creme de cacao',
#  'apple flavored brandy',
#  'orange half-wheel',
#  'lavender syrup',
#  'lemon and/or orange zest spiral(s)',
#  'orange twist',
#  'orange and/or lemon zest spiral',
#  'cinnamon stick',
#  'almond extract',
#  'green olive',
#  'grapefruit twist',
#  'almond milk',
#  'thyme sprig',
#  'fresh mint leaf',
#  'vanilla liqueur and 3 oz',
#  'b & b',
#  'cold brewed chai tea',
#  'grapefruit bitters',
#  "peychaud's bitters",
#  'orgeat syrup',
#  'ketchup',
#  'grapefruit twist or skewered raspberry',
#  'edible flowers',
#  'light cream (if desired)',
#  'sweet pickle slice',
#  'chilled american sparkling wine',
#  'vinegar',
#  'port',
#  'peach',
#  'cold brewed espresso coffee',
#  'crushed ice',
#  'root beer',
#  'grated bittersweet chocolate',
#  'whole cloves',
#  'acai berry flavored vodka',
#  'bitter lemon soda',
#  'lemon peel',
#  'each cranberry juice orange juice pineapple juice lemon juice',
#  'sugar syrup',
#  'apricot nectar',
#  'pomegranate molasses',
#  'cayenne pepper',
#  'raspberry juice',
#  'honey',
#  'each fresh lime juice lemon juice pineapple juie and passion fruit syrup',
#  'heavy cream whipped',
#  'mango juice',
#  'sugar cube',
#  'each orange juice and simple syrup',
#  'prepared horseradish',
#  'salt',
#  'sweet vermouth',
#  'peychaud bitters',
#  'jalapeno-infused tequila',
#  'guava puree',
#  'vs cognac',
#  'mango nectar',
#  'creme fraiche',
#  'pomegranate molasses (available at middle eastern grocers)',
#  "the bitter truth's jerry thomas' own decanter bitters",
#  'balsamic vinegar',
#  'grapefruit soda',
#  'rhubarb bitters',
#  'each triple sec simple syrup',
#  'unsprayed rose petal',
#  'sour mix',
#  'orange and lemon wheels maraschino cherry',
#  'lemon and lime wheels',
#  'pomegranate syrup',
#  "chilled moscato d'asti or sweet sparkling wine",
#  'orange wheel',
#  'pineapple wedge maraschino cherry',
#  'iced tea',
#  'pepper',
#  'italian preserved cherry',
#  'grapefruit marmalade',
#  'each fresh lemon juice and cranberry juice',
#  '7-up',
#  'cloves',
#  'orange wheel maraschino cherry',
#  'lime soda',
#  'each fresh orange juice pineapple juice cranberry juice',
#  'each cranberry juice orange juice spiced rum',
#  'freshly grated nutmeg',
#  'grapefruit twist flamed',
#  'pineapple wedge',
#  'jamaican ginger beer',
#  'edible flower such as nasturtium',
#  'fresh seasonal fruit',
#  'orange and/or lemon zest',
#  'lemon wheel maraschino cherry',
#  'african rum',
#  'each fresh lemon juice triple sec',
#  'rum-soaked black cherry',
#  'each worcestershire sauce salt ground black pepper',
#  'freshly ground black pepper',
#  'hot red pepper sauce',
#  'each simple syrup angostura bitters',
#  'thin pear slice',
#  'lemon wheel orange wheel maraschino cherry',
#  'lemon wedge',
#  'ground cinnamon',
#  'lime wedge; honeydew melon wedge or maraschino cherry',
#  'chocolate bitters',
#  'rock candy syrup or simple syrup',
#  'each fresh lemon juice angostura bitters',
#  'cream of coconut',
#  'simple syrup scant',
#  'each simple syrup grenadine',
#  "tiki bitters such as bittermen's elemakule",
#  'orange zest spiral maraschino cherry',
#  'sparkling apple cider',
#  'orange twist flamed',
#  'each orange juice and sweet sherry',
#  'soda water (optional)',
#  'freshly grated nutmeg ground cinnamon',
#  'fresh grenadine',
#  'orange blossom water',
#  'dehydrated orange wheel',
#  'rosemary sprig',
#  'orange blossoms (optional): orange wedge',
#  'each fresh lemon juice fresh lime juice',
#  'celery salt',
#  'fresh raspberries and strawberries 2 peach slices maraschino cherry',
#  'orange and lime wheels',
#  'fresh raspberry',
#  'long thyme sprigs',
#  'orange half-wheel maraschino cherry',
#  'orange and lemon wheels',
#  'stick of cotton candy',
#  'whole egg and grated nutmet',
#  'chilled sparkling wine or champagne',
#  'strawberry',
#  'fresh lemon juice and 3 oz',
#  'soda water orange and lemon wheels maraschino cherry',
#  'soda water orange and lemon wheels',
#  'simple syrup 3/4 oz',
#  'orange twist green olive',
#  'fresh mint sprig',
#  'cranberry juice lemon wheel',
#  'peach slice lemon wheel',
#  'mole bitters 1 oz',
#  'passion fruit juice basil leaf',
#  'canned pitted lychee nut stuffed with a small pineapple leaf',
#  'simple syrup 1/2 oz',
#  'sparkling wine raspberry and cucumber',
#  'celery stick',
#  'lime wheel maraschino cherry',
#  'chilled champagne  orange half-wheel lime wheel',
#  'apple schnapps grapefruit twist',
#  'each cranberry juice and orange juice',
#  'banana',
#  'lime soda orange wheel maraschino cherry',
#  'peach slice',
#  'lemon twist maraschino cherry',
#  'lemon wheel pineapple chunk',
#  'lime soda pineapple wedge maraschino cherry or lime wheel',
#  'light cream 1/2 oz',
#  "tiki (such as bittermen's 'elemakule) or angostura bitters (optional) garnish: fresh mint sprig",
#  'powdered nutmeg',
#  'mango slice',
#  'lemon wheel',
#  'whipped cream and 3/4 oz',
#  'green apple slice lime wedge',
#  'orange zest',
#  'freshly grated nutmeg orange wheel',
#  'champagne',
#  'egg yolk 1 oz',
#  'lemon orange and pineapple slices; maraschino cherry; fresh mint sprig dipped in sugar',
#  'lemon orange and pineapple slices; maraschino cherry',
#  'orange marmalade grapefruit twist',
#  'champagne chopped fresh mint',
#  'celery stalk lemon wedge',
#  'freshly ground black pepper to taste lime wedge celery stalk',
#  'fresh blackberries and raspberries',
#  'fresh lemon juice lemon twiste fresh pomegranate seeds',
#  'soda water strawberry slide fresh basil leaf',
#  'ginger ale strawberry slice',
#  'lime wheel skewered with blueberry and bing cherry',
#  'fresh lime juice whole strawberry',
#  'cucumber slice fresh mint sprig',
#  'ginger beer 1 oz',
#  'grenadine maraschino cherry',
#  'each fresh lemon juice simple syrup 1 lime wheel',
#  'fresh mint sprig; pineapple wedge skewered with maraschino cherry',
#  'fresh lime juice lime wheel',
#  'small pineapple slice',
#  'ginger ale lime wheel',
#  'champagne or sparkling wine mint sprig',
#  'lemon-lime soda cucumber slice',
#  'golden delicious apple wedge',
#  'angostura bitters flamed lemon twist',
#  'whiskey barrel bitters',
#  'almond or orgeat syrup',
#  'lime twist',
#  'lemon half-wheel maraschino cherry',
#  'blood orange wheel',
#  'grenadine lime wheel',
#  'agave nectar strawberry slice',
#  'angostura bitters lime wheel',
#  'jalapeno hot pepper sauce cucumber slice',
#  'raspberries lemon twist']

# %%
sorted(cocktail_ingredients)
# Out:
# ['100-proof vodka',
#  '151-proof rum',
#  '17-year-old j. wray and nephew ltd. rum',
#  '7-up',
#  'absinthe',
#  'absinthe',
#  'absinthe or pastis',
#  'absinthe substitute',
#  'acai berry flavored vodka',
#  'african rum',
#  'agave nectar',
#  'agave nectar strawberry slice',
#  'aged rhum agricole',
#  'allspice liqueur (pimento dram)',
#  'almond extract',
#  'almond milk',
#  'almond or orgeat syrup',
#  'amaretto',
#  'amaretto di saronno',
#  'amaro',
#  'amaro nonino',
#  'amer picon or torani amer',
#  'amontillado sherry',
#  'anejo tequila',
#  'anejo tequila',
#  'angostura bitters',
#  'angostura bitters',
#  'angostura bitters flamed lemon twist',
#  'angostura bitters lime wheel',
#  'anis',
#  'anisette',
#  'aperol',
#  'apple brandy',
#  'apple cider',
#  'apple flavored brandy',
#  'apple juice',
#  'apple schnapps',
#  'apple schnapps grapefruit twist',
#  'apple slice',
#  'applejack',
#  'applejack',
#  'apricot flavored brandy',
#  'apricot nectar',
#  'apricot-flavored brandy',
#  'aquavit',
#  'aquavit or vodka',
#  'armagnac',
#  'aromatic bitters',
#  'b & b',
#  'bacardi rum',
#  'balsamic vinegar',
#  'banana',
#  'batavia arrack or light rum',
#  'becherovka (czech digestif)',
#  'benedictine',
#  'bing cherries',
#  'bison grass vodka (zubrowka)',
#  'bitter lemon soda',
#  'bitters',
#  'bitters',
#  'black cherry juice',
#  'black cherry-flavored vodka',
#  'black licorice stick',
#  'black raspberry liqueur',
#  'blackberry liqueur',
#  'blackberry-flavored brandy',
#  'blanco tequila',
#  'blended scotch whiskey',
#  'blended scotch whiskey',
#  'blended whiskey',
#  'blended whiskey',
#  'blood or navel orange half-wheel',
#  'blood orange juice',
#  'blood orange liqueur',
#  'blood orange wheel',
#  'blue curacao',
#  'blueberries',
#  'boiling water',
#  'bourbon',
#  'bourbon',
#  'bourbon or rye whiskey',
#  'bourbon or rye whiskey',
#  'bourbon whiskey',
#  'bourbon whiskey',
#  'brandy',
#  'brandy preferably spanish',
#  'brown sugar cube such as demerara',
#  'butterscotch schnapps',
#  'cachaca',
#  'cachaca (brazilian rum)',
#  'calvados',
#  'calvados apple brandy or applejack',
#  'campari',
#  'canadian whisky',
#  'canned coconut milk',
#  'canned pitted lychee nut stuffed with a small pineapple leaf',
#  'carbonated water',
#  'carbonated water',
#  'carbonated water',
#  'catsup',
#  'cayenne pepper',
#  'celery salt',
#  'celery stalk lemon wedge',
#  'celery stick',
#  'champagne',
#  'champagne',
#  'champagne chopped fresh mint',
#  'champagne or sparkling wine mint sprig',
#  'cherry heering',
#  'cherry liqueur',
#  'cherry vodka',
#  'cherry-flavored brandy',
#  'cherry-flavored brandy superfine sugar',
#  'chile syrup',
#  'chilled american sparkling wine',
#  'chilled beer or ale',
#  'chilled champagne',
#  'chilled champagne',
#  'chilled champagne  orange half-wheel lime wheel',
#  "chilled moscato d'asti or sweet sparkling wine",
#  'chilled passion fruit juice',
#  'chilled rhine wine or sauterne',
#  'chilled sparkling wine',
#  'chilled sparkling wine or champagne',
#  'chilled stout',
#  'chocolate bitters',
#  'cider',
#  'cinnamon schnapps',
#  'cinnamon stick',
#  'cinnamon sticks',
#  'citrus-flavored vodka',
#  'clam juice',
#  'claret',
#  'clementine or mandarin orange',
#  'cloves',
#  'club soda',
#  'coarse salt',
#  'coconut liqueur',
#  'coconut milk',
#  'coconut rum',
#  'coconut-flavored rum',
#  'coffee liqueur',
#  'coffee-flavored brandy',
#  'coffee-flavored liqueur',
#  'cognac',
#  'cointreau or triple sec',
#  'cointreau triple sec',
#  'cola',
#  'cola',
#  'cold beef bouillon',
#  'cold brewed black tea preferably japanese',
#  'cold brewed chai tea',
#  'cold brewed coffee',
#  'cold brewed espresso coffee',
#  'cold brewed green tea',
#  'cold water',
#  'collins mix',
#  'concord grape juice',
#  'cranberry juice',
#  'cranberry juice lemon wheel',
#  'cream of coconut',
#  'cream sherry',
#  'cream sherry',
#  'crema di limoncello',
#  'creme de banana',
#  'creme de cacao',
#  'creme de cacao (brown)',
#  'creme de cacao (white)',
#  'creme de cassis',
#  'creme de menthe',
#  'creme de menthe (white)',
#  'creme de noyaux',
#  'creme de peche',
#  'creme de violette',
#  'creme fraiche',
#  'creme yvette',
#  'creole shrubb (rum-based orange liqueur)',
#  'crushed ice',
#  'crushed pineapple',
#  'cucumber',
#  'cucumber slice fresh mint sprig',
#  'cucumber slices',
#  'cucumber slices chopped',
#  'curacao',
#  'cynar',
#  'danish cherry wine',
#  'dark creme de cacao',
#  'dark rum',
#  'dark rum preferably jamaican',
#  'dehydrated orange wheel',
#  'demerara syrup',
#  'desmond & duff scotch whisky',
#  'dill pickle brine',
#  'drambuie',
#  'dried orange peel',
#  'dry gin',
#  'dry sherry',
#  'dry vermouth',
#  'dubonnet',
#  'dubonnet',
#  'dubonnet rouge',
#  'each citrus-flavored vodka and orange-flavored vodka',
#  'each cranberry juice and orange juice',
#  'each cranberry juice orange juice pineapple juice lemon juice',
#  'each cranberry juice orange juice spiced rum',
#  'each dark rum light rum',
#  'each fresh lemon juice and cranberry juice',
#  'each fresh lemon juice angostura bitters',
#  'each fresh lemon juice fresh lime juice',
#  'each fresh lemon juice simple syrup 1 lime wheel',
#  'each fresh lemon juice triple sec',
#  'each fresh lime juice jamaica rum grenadine',
#  'each fresh lime juice lemon juice pineapple juie and passion fruit syrup',
#  'each fresh orange juice pineapple juice cranberry juice',
#  'each light rum gin vodka blanco tequila blue curacao',
#  'each lillet blanc and lillet rouge',
#  'each orange juice and simple syrup',
#  'each orange juice and sweet sherry',
#  'each simple syrup angostura bitters',
#  'each simple syrup grenadine',
#  'each simple syrup light rum dark rum',
#  'each triple sec simple syrup',
#  'each vodka tequila blanco triple sec',
#  'each worcestershire sauce salt ground black pepper',
#  'edible flower such as nasturtium',
#  'edible flowers',
#  'egg',
#  'egg white',
#  'egg yolk',
#  'egg yolk 1 oz',
#  'elderflower liqueur',
#  'falernum',
#  'fernet-branca',
#  'for glass lemon wedge coarse salt',
#  'forbidden fruit',
#  'fresh apple cider',
#  'fresh basil leaves',
#  'fresh blackberries and raspberries',
#  'fresh carrot juice',
#  'fresh celery juice',
#  'fresh cherry tomatoes',
#  'fresh cilantro leaves',
#  'fresh cilantro sprigs',
#  'fresh ginger',
#  'fresh grapefruit juice',
#  'fresh grenadine',
#  'fresh lemon juice',
#  'fresh lemon juice and 3 oz',
#  'fresh lemon juice lemon twiste fresh pomegranate seeds',
#  'fresh lemon or lime juice',
#  'fresh lime juice',
#  'fresh lime juice (reserve 1/2 lime shell for garnish)',
#  'fresh lime juice lime wheel',
#  'fresh lime juice whole strawberry',
#  'fresh mint leaf',
#  'fresh mint leaves',
#  'fresh mint leaves',
#  'fresh mint sprig',
#  'fresh mint sprig; pineapple wedge skewered with maraschino cherry',
#  'fresh orange juice',
#  'fresh orange juice and orange wheel',
#  'fresh raspberries and strawberries 2 peach slices maraschino cherry',
#  'fresh raspberry',
#  'fresh rosemary sprig',
#  'fresh ruby red grapefruit juice',
#  'fresh sage leaves',
#  'fresh seasonal fruit',
#  'fresh strawberries cut in half',
#  'fresh strawberries cut in halves',
#  'fresh white or ruby red grapefruit juice',
#  'freshly grated nutmeg',
#  'freshly grated nutmeg ground cinnamon',
#  'freshly grated nutmeg orange wheel',
#  'freshly ground black pepper',
#  'freshly ground black pepper to taste lime wedge celery stalk',
#  'galliano',
#  'georgia moon corn whiskey',
#  'gin',
#  'gin & ginger ale',
#  'ginger ale',
#  'ginger ale',
#  'ginger ale lime wheel',
#  'ginger ale or soda water',
#  'ginger ale strawberry slice',
#  'ginger beer',
#  'ginger beer 1 oz',
#  'ginger liqueur',
#  'ginger syrup',
#  'gingerbread liqueur',
#  'gold rum',
#  'gold tequila',
#  'golden delicious apple wedge',
#  'grand marnier',
#  'grape juice',
#  'grapefruit bitters',
#  'grapefruit juice',
#  'grapefruit marmalade',
#  'grapefruit soda',
#  'grapefruit twist',
#  'grapefruit twist flamed',
#  'grapefruit twist or skewered raspberry',
#  'grapefruit-flavored soda',
#  'grapefruit-flavored vodka',
#  'grated bittersweet chocolate',
#  'green apple slice lime wedge',
#  'green chartreuse',
#  'green creme de menthe',
#  'green olive',
#  'grenadine',
#  'grenadine lime wheel',
#  'grenadine maraschino cherry',
#  'ground cinnamon',
#  'guava puree',
#  'half-and-half',
#  'hard cider',
#  'heavy cream',
#  'heavy cream whipped',
#  'hennessy v.s cognac',
#  'honey',
#  'honey liqueur',
#  'honey syrup',
#  'honey-currant syrup',
#  'hot apple cider',
#  'hot black coffee',
#  'hot red pepper sauce',
#  'hot red pepper sauce',
#  'hot shot tropical fruit liqueur',
#  'hot tea',
#  'iced tea',
#  'irish cream liqueur',
#  'irish whiskey',
#  'italian preserved cherry',
#  'jalapeno hot pepper sauce cucumber slice',
#  'jalapeno-infused tequila',
#  'jamaica rum',
#  'jamaican ginger beer',
#  'juice of a blood orange',
#  'juice of a lemon',
#  'juice of a lime',
#  'juice of lemon or lime',
#  'juice of orange',
#  'ketchup',
#  'kirschwasser',
#  'kummel',
#  'lavender syrup',
#  'lemon',
#  'lemon',
#  'lemon and lime wheels',
#  'lemon and/or orange zest spiral(s)',
#  'lemon half-wheel maraschino cherry',
#  'lemon juice',
#  'lemon or lime juice',
#  'lemon or lime wedge',
#  'lemon or orange sherbet',
#  'lemon orange and pineapple slices; maraschino cherry',
#  'lemon orange and pineapple slices; maraschino cherry; fresh mint sprig dipped in sugar',
#  'lemon peel',
#  'lemon quarter-wheel',
#  'lemon slice',
#  'lemon twist',
#  'lemon twist',
#  'lemon twist (optional)',
#  'lemon twist maraschino cherry',
#  'lemon wedge',
#  'lemon wedge celery salt',
#  'lemon wedge cinnamon sugar',
#  'lemon wedge coarse salt',
#  'lemon wedge superfine sugar',
#  'lemon wedge superfine sugar  long wide spiral of orange zest',
#  'lemon wedges',
#  'lemon wheel',
#  'lemon wheel coarse salt',
#  'lemon wheel maraschino cherry',
#  'lemon wheel orange wheel maraschino cherry',
#  'lemon wheel pineapple chunk',
#  'lemon-flavored vodka',
#  'lemon-lime soda',
#  'lemon-lime soda cucumber slice',
#  'lemonade',
#  'light cream',
#  'light cream (if desired)',
#  'light cream 1/2 oz',
#  'light or dark rum',
#  'light rum',
#  'light sweet cream',
#  'light vermouth',
#  'lillet blanc',
#  'lillet rouge',
#  'lime',
#  'lime juice',
#  'lime juice coarse salt',
#  'lime liqueur',
#  'lime soda',
#  'lime soda orange wheel maraschino cherry',
#  'lime soda pineapple wedge maraschino cherry or lime wheel',
#  'lime twist',
#  'lime vodka',
#  'lime wedge',
#  'lime wedge coarse salt',
#  'lime wedge coarse salt',
#  'lime wedge pink sanding sugar',
#  'lime wedge superfine sugar',
#  'lime wedge superfine sugar',
#  'lime wedge superfine sugar or coarse salt (optional)',
#  'lime wedge sweet chili powder',
#  'lime wedge; honeydew melon wedge or maraschino cherry',
#  'lime wedges',
#  'lime wedges',
#  'lime wheel',
#  'lime wheel maraschino cherry',
#  'lime wheel skewered with blueberry and bing cherry',
#  'limoncello',
#  'long thyme sprigs',
#  'lump of sugar',
#  'lump sugar',
#  'lychee liqueur',
#  'madeira',
#  'mandarine napoleon liqueur',
#  'mango juice',
#  'mango nectar',
#  'mango slice',
#  'mango-flavored vodka',
#  'manzanilla sherry',
#  'maple syrup',
#  'maple syrup (grade b or medium-amber)',
#  'maraschino',
#  'maraschino cherry',
#  'maraschino liqueur',
#  'margarita mix',
#  'medium eggs',
#  'melon liqueur',
#  'mezcal',
#  'milk',
#  'milk or half-and-half',
#  'minced ginger',
#  'mint leaves',
#  'mint sprigs',
#  'mint syrup',
#  'mint-flavored gin',
#  'mole bitters 1 oz',
#  'mountain dew',
#  'mr. boston apricot flavored brandy',
#  'mr. boston creme de menthe',
#  'mr. boston creme de noyaux',
#  'mr. boston five star brandy',
#  'mr. boston gin',
#  'mr. boston rum',
#  'mr. boston triple sec',
#  'mr. boston vodka',
#  'muscatel wine',
#  'nan',
#  'old kentucky tavern bourbon whiskey',
#  'old mr. boston 100 proof vodka',
#  'old mr. boston anisette',
#  'old mr. boston apricot flavored brandy',
#  'old mr. boston blended whiskey',
#  'old mr. boston creme de cacao',
#  'old mr. boston creme de menthe (white)',
#  'old mr. boston dry gin',
#  'old mr. boston five star brandy',
#  'old mr. boston grape vodka',
#  'old mr. boston green creme de menthe',
#  'old mr. boston imported rum',
#  'old mr. boston kummel',
#  'old mr. boston orange flavored gin',
#  'old mr. boston rock and rye',
#  'old mr. boston rum',
#  'old mr. boston sloe gin',
#  'old mr. boston tequila',
#  'old mr. boston triple sec',
#  'old mr. boston triple sec',
#  'old mr. boston vodka',
#  'old mr. boston white creme de cacao',
#  'old mr. boston white creme de menthe',
#  'old mr. boston wild cherry flavored brandy',
#  'old thompson blended whiskey',
#  'old tom gin',
#  'olive brine',
#  'oloroso sherry',
#  'orange',
#  'orange and lemon wheels',
#  'orange and lemon wheels maraschino cherry',
#  'orange and lime wheels',
#  'orange and/or lemon zest',
#  'orange and/or lemon zest spiral',
#  'orange bitters',
#  'orange bitters (if desired)',
#  'orange blossom water',
#  'orange blossoms (optional): orange wedge',
#  'orange curacao',
#  'orange flavored gin',
#  'orange half-wheel',
#  'orange half-wheel maraschino cherry',
#  'orange juice',
#  'orange juice',
#  'orange juice',
#  'orange liqueur',
#  'orange marmalade grapefruit twist',
#  'orange peel',
#  'orange twist',
#  'orange twist flamed',
#  'orange twist green olive',
#  'orange wheel',
#  'orange wheel maraschino cherry',
#  'orange zest',
#  'orange zest spiral maraschino cherry',
#  'orange-flavored vodka',
#  'orgeat or almond syrup',
#  'orgeat syrup',
#  'palo cortado or oloroso sherry',
#  'passion fruit juice',
#  'passion fruit juice basil leaf',
#  'passion fruit syrup',
#  'pastis',
#  'peach',
#  'peach bitters',
#  'peach liqueur',
#  'peach puree',
#  'peach schnapps',
#  'peach slice',
#  'peach slice lemon wheel',
#  'peach slice skinned',
#  'peach-flavored brandy',
#  'peach-flavored vodka',
#  'pear brandy',
#  'pear liqueur',
#  'pear-flavored vodka',
#  'pedro ximenez sherry',
#  'peeled and chopped fresh ginger',
#  'pepper',
#  'pepper and salt',
#  'peppermint schnapps',
#  'peychaud bitters',
#  "peychaud's bitters",
#  "pimm's no. 1 cup",
#  'pineapple',
#  'pineapple',
#  'pineapple juice',
#  'pineapple or grapefruit juice',
#  'pineapple wedge',
#  'pineapple wedge maraschino cherry',
#  'pisco',
#  'pomegranate juice',
#  'pomegranate molasses',
#  'pomegranate molasses (available at middle eastern grocers)',
#  'pomegranate syrup',
#  'port',
#  'port',
#  'powdered nutmeg',
#  'powdered sugar',
#  'powdered sugar',
#  'powdered sugar',
#  'prepared horseradish',
#  'punt e mes',
#  'ramazzotti amaro',
#  'raspberries lemon twist',
#  'raspberry ice cream',
#  'raspberry juice',
#  'raspberry syrup',
#  'raspberry yogurt',
#  'raspberry-flavored liqueur',
#  'raspberry-flavored vodka',
#  'red grapes',
#  'red wine',
#  'red wine',
#  'reposado blanco tequila',
#  'reposado tequila',
#  'rhubarb bitters',
#  'rhubarb syrup',
#  'ripe pear',
#  'rock and rye',
#  'rock candy syrup or simple syrup',
#  'root beer',
#  'rose water',
#  "rose's lime juice",
#  'rosemary sprig',
#  'roses lime juice',
#  'ruby port',
#  'rum-soaked black cherry',
#  'rye or bourbon whiskey',
#  'rye whiskey',
#  'sake',
#  'salt',
#  'sambuca',
#  'scotch',
#  'scotch whiskey',
#  'shaved ice',
#  'simple syrup',
#  'simple syrup 1/2 oz',
#  'simple syrup 3/4 oz',
#  'simple syrup scant',
#  'single-malt scotch whisky',
#  'slice peeled fresh ginger',
#  'sloe gin',
#  'small pineapple slice',
#  'smoky scotch such as laphroaig',
#  'smoky scotch whisky such as islay or skye',
#  'smoky scotch whisky such as laphroaig',
#  'soda water',
#  'soda water (optional)',
#  'soda water or ginger ale',
#  'soda water orange and lemon wheels',
#  'soda water orange and lemon wheels maraschino cherry',
#  'soda water strawberry slide fresh basil leaf',
#  'sour mix',
#  'sparkling apple cider',
#  'sparkling wine raspberry and cucumber',
#  'spiced rum',
#  'splash triple sec',
#  'springs mint',
#  'stick of cotton candy',
#  'straight rye whiskey',
#  'straight rye whisky',
#  'strawberries cut into halves',
#  'strawberry',
#  'strawberry chopped',
#  'strawberry liqueur',
#  'strawberry schnapps',
#  'strega',
#  'sugar',
#  'sugar cube',
#  'sugar syrup',
#  'superfine sugar',
#  'swedish punch',
#  'sweet cream',
#  'sweet pickle brine',
#  'sweet pickle slice',
#  'sweet sherry',
#  'sweet sherry preferably pedro ximenez',
#  'sweet vermouth',
#  'sweet vermouth',
#  'tanqueray gin',
#  'tawny port',
#  'tennessee whiskey',
#  'tequila',
#  "the bitter truth's jerry thomas' own decanter bitters",
#  'thin pear slice',
#  'thin peeled fresh ginger',
#  'thyme sprig',
#  "tiki (such as bittermen's 'elemakule) or angostura bitters (optional) garnish: fresh mint sprig",
#  "tiki bitters such as bittermen's elemakule",
#  'tomato catsup',
#  'tomato juice',
#  'tomato-clam juice',
#  'tonic',
#  'tonic water',
#  'triple sec',
#  'tropical fruit schnapps',
#  'unsprayed rose petal',
#  'unsweetened grape juice',
#  'v8 cocktail juice',
#  'vanilla ice cream',
#  'vanilla liqueur',
#  'vanilla liqueur and 3 oz',
#  "vanilla syrup preferably b.a. reynold's",
#  'vanilla-flavored vodka',
#  'vanilla-infused bourbon',
#  'vermouth',
#  'vinegar',
#  'vodka',
#  'vs cognac',
#  'warm milk',
#  'water',
#  'water',
#  'whipped cream',
#  'whipped cream and 3/4 oz',
#  'whiskey barrel bitters',
#  'white chocolate liqueur',
#  'white creme de cacao',
#  'white creme de menthe',
#  'white curacao',
#  'white curacao or triple sec',
#  'white grapes',
#  'white or dark creme de cacao',
#  'white port wine',
#  'white rum',
#  'white whiskey',
#  'whole cloves',
#  'whole egg',
#  'whole egg',
#  'whole egg and grated nutmet',
#  'whole milk',
#  'whole strawberry',
#  'whole strawberry hulled',
#  'wide spiral of lemon zest',
#  'wine (port cream sherry claret burgundy or madeira)',
#  'worcestershire sauce',
#  'yellow chartreuse']

# %%
all_ingredients = list(set(recipe_ingredients).union(set(cocktail_ingredients)))
len(all_ingredients)
# Out:
# 15329

# %%
len(cocktail_ingredients)
# Out:
# 688

# %%
ingredient_encoder = LabelEncoder()
ingredient_encoder.fit(all_ingredients)
ingredient_encoder
# Out:
# (15329,)

# %%
recipe_inputs = [name.split(" ") for name in recipe_df["name"].astype(str).str.strip()]
recipe_inputs = [" ".join([word for word in recipe if word != ""]) for recipe in recipe_inputs]
recipe_outputs = list(recipe_df["ingredients"].apply(transform_str2list))
recipe_outputs = [ingredient_encoder.transform(recipe) for recipe in tqdm(recipe_outputs)]

recipe_outputs
# Out:
#   0%|▏                                                                          | 523/231637 [00:08<1:03:28, 60.68it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_59388/3303859568.py in <module>
#       2 recipe_inputs = [" ".join([word for word in recipe if word != ""]) for recipe in recipe_inputs]
#       3 recipe_outputs = list(recipe_df["ingredients"].apply(transform_str2list))
# ----> 4 recipe_outputs = [ingredient_encoder.transform(recipe) for recipe in tqdm(recipe_outputs)]
#       5
#       6 recipe_outputs
#
# ~\AppData\Local\Temp/ipykernel_59388/3303859568.py in <listcomp>(.0)
#       2 recipe_inputs = [" ".join([word for word in recipe if word != ""]) for recipe in recipe_inputs]
#       3 recipe_outputs = list(recipe_df["ingredients"].apply(transform_str2list))
# ----> 4 recipe_outputs = [ingredient_encoder.transform(recipe) for recipe in tqdm(recipe_outputs)]
#       5
#       6 recipe_outputs
#
# x:\volundrai\cocktail-creator-ai\env\lib\site-packages\sklearn\preprocessing\_label.py in transform(self, y)
#     136             return np.array([])
#     137
# --> 138         return _encode(y, uniques=self.classes_)
#     139
#     140     def inverse_transform(self, y):
#
# x:\volundrai\cocktail-creator-ai\env\lib\site-packages\sklearn\utils\_encode.py in _encode(values, uniques, check_unknown)
#     180     if values.dtype.kind in "OUS":
#     181         try:
# --> 182             return _map_to_integer(values, uniques)
#     183         except KeyError as e:
#     184             raise ValueError(f"y contains previously unseen labels: {str(e)}")
#
# x:\volundrai\cocktail-creator-ai\env\lib\site-packages\sklearn\utils\_encode.py in _map_to_integer(values, uniques)
#     123 def _map_to_integer(values, uniques):
#     124     """Map values based on its position in uniques."""
# --> 125     table = _nandict({val: i for i, val in enumerate(uniques)})
#     126     return np.array([table[v] for v in values])
#     127
#
# x:\volundrai\cocktail-creator-ai\env\lib\site-packages\sklearn\utils\_encode.py in <dictcomp>(.0)
#     123 def _map_to_integer(values, uniques):
#     124     """Map values based on its position in uniques."""
# --> 125     table = _nandict({val: i for i, val in enumerate(uniques)})
#     126     return np.array([table[v] for v in values])
#     127
#
# KeyboardInterrupt:

# %%
cocktail_inputs = [name.lower().split(" ") for name in cocktail_df["name"].astype(str).str.strip()]
cocktail_inputs = [" ".join([word for word in cocktail if word != ""]) for cocktail in cocktail_inputs]
cocktail_df["Ingredient_list"] = cocktail_df["ingredient-1"].astype(str).str.replace("NaN", "") + ","
cocktail_df["Ingredient_list"] += cocktail_df["ingredient-2"].astype(str).str.replace("NaN", "") + ","
cocktail_df["Ingredient_list"] += cocktail_df["ingredient-3"].astype(str).str.replace("NaN", "") + ","
cocktail_df["Ingredient_list"] += cocktail_df["ingredient-4"].astype(str).str.replace("NaN", "") + ","
cocktail_df["Ingredient_list"] += cocktail_df["ingredient-5"].astype(str).str.replace("NaN", "") + ","
cocktail_df["Ingredient_list"] += cocktail_df["ingredient-6"].astype(str).str.replace("NaN", "")
cocktail_df["Ingredient_list"] = cocktail_df["Ingredient_list"].str.replace(",,", ",")
cocktail_df["Ingredient_list"] = cocktail_df["Ingredient_list"].str.replace(",,", ",")
cocktail_df["Ingredient_list"] = cocktail_df["Ingredient_list"].str.replace(",,", ",")
cocktail_df["Ingredient_list"] = cocktail_df["Ingredient_list"].str.replace(",,", ",")
cocktail_df["Ingredient_list"] = cocktail_df["Ingredient_list"].str.replace(",,", ",")
cocktail_outputs = list(cocktail_df["Ingredient_list"].str.strip())
cocktail_outputs = [[ing.strip().lower() for ing in cocktail.split(",") if ing != ""] for cocktail in cocktail_outputs]
cocktail_outputs = [ingredient_encoder.transform(recipe) for recipe in tqdm(cocktail_outputs)]

cocktail_inputs
# Out:
#   0%|                                                                                          | 0/990 [00:00<?, ?it/s]
#
#   1%|▍                                                                                 | 6/990 [00:00<00:16, 58.82it/s]
#
#   1%|▉                                                                                | 12/990 [00:00<00:16, 58.82it/s]
#
#   2%|█▍                                                                               | 18/990 [00:00<00:16, 59.22it/s]
#
#   2%|█▉                                                                               | 24/990 [00:00<00:16, 59.06it/s]
#
#   3%|██▍                                                                              | 30/990 [00:00<00:16, 58.36it/s]
#
#   4%|██▉                                                                              | 36/990 [00:00<00:16, 57.65it/s]
#
#   4%|███▍                                                                             | 42/990 [00:00<00:16, 57.49it/s]
#
#   5%|███▉                                                                             | 48/990 [00:00<00:16, 57.82it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# x:\volundrai\cocktail-creator-ai\env\lib\site-packages\sklearn\utils\_encode.py in _encode(values, uniques, check_unknown)
#     181         try:
# --> 182             return _map_to_integer(values, uniques)
#     183         except KeyError as e:
#
# x:\volundrai\cocktail-creator-ai\env\lib\site-packages\sklearn\utils\_encode.py in _map_to_integer(values, uniques)
#     125     table = _nandict({val: i for i, val in enumerate(uniques)})
# --> 126     return np.array([table[v] for v in values])
#     127
#
# x:\volundrai\cocktail-creator-ai\env\lib\site-packages\sklearn\utils\_encode.py in <listcomp>(.0)
#     125     table = _nandict({val: i for i, val in enumerate(uniques)})
# --> 126     return np.array([table[v] for v in values])
#     127
#
# x:\volundrai\cocktail-creator-ai\env\lib\site-packages\sklearn\utils\_encode.py in __missing__(self, key)
#     119             return self.nan_value
# --> 120         raise KeyError(key)
#     121
#
# KeyError: 'fresh raspberries and strawberries'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_59388/954140593.py in <module>
#      14 cocktail_outputs = list(cocktail_df["Ingredient_list"].str.strip())
#      15 cocktail_outputs = [[ing.strip().lower() for ing in cocktail.split(",") if ing != ""] for cocktail in cocktail_outputs]
# ---> 16 cocktail_outputs = [ingredient_encoder.transform(recipe) for recipe in tqdm(cocktail_outputs)]
#      17
#      18 cocktail_inputs
#
# ~\AppData\Local\Temp/ipykernel_59388/954140593.py in <listcomp>(.0)
#      14 cocktail_outputs = list(cocktail_df["Ingredient_list"].str.strip())
#      15 cocktail_outputs = [[ing.strip().lower() for ing in cocktail.split(",") if ing != ""] for cocktail in cocktail_outputs]
# ---> 16 cocktail_outputs = [ingredient_encoder.transform(recipe) for recipe in tqdm(cocktail_outputs)]
#      17
#      18 cocktail_inputs
#
# x:\volundrai\cocktail-creator-ai\env\lib\site-packages\sklearn\preprocessing\_label.py in transform(self, y)
#     136             return np.array([])
#     137
# --> 138         return _encode(y, uniques=self.classes_)
#     139
#     140     def inverse_transform(self, y):
#
# x:\volundrai\cocktail-creator-ai\env\lib\site-packages\sklearn\utils\_encode.py in _encode(values, uniques, check_unknown)
#     182             return _map_to_integer(values, uniques)
#     183         except KeyError as e:
# --> 184             raise ValueError(f"y contains previously unseen labels: {str(e)}")
#     185     else:
#     186         if check_unknown:
#
# ValueError: y contains previously unseen labels: 'fresh raspberries and strawberries'
#   5%|███▉                                                                             | 48/990 [00:20<00:16, 57.82it/s]

# %%
# Out:
# [['light rum', 'passion fruit syrup', 'lemon juice', 'lime juice'],
#  ['light rum', 'sweet vermouth', 'juice of orange', 'juice of a lime'],
#  ['apple schnapps', 'cinnamon schnapps', 'apple slice'],
#  ['juice of a lime', 'powdered sugar', 'light rum'],
#  ['dark rum',
#   'cranberry juice',
#   'pineapple juice',
#   'orange curacao',
#   'sour mix'],
#  ['bourbon whiskey',
#   'fresh lemon juice',
#   'simple syrup',
#   'soda water',
#   'orange and lemon wheels',
#   'maraschino cherry'],
#  ['light rum', 'cherry-flavored brandy', 'light cream'],
#  ['light rum', 'lime juice', 'triple sec', 'maraschino'],
#  ['light rum', 'creme de baa', 'chilled champagne'],
#  ['amaretto', 'fresh lemon juice', 'simple syrup', 'soda water'],
#  ['scotch whiskey',
#   'fresh carrot juice',
#   'tawny port',
#   'fresh lemon juice',
#   'agave nectar'],
#  ['bacardi rum', 'juice of a lime', 'grenadine'],
#  ['light rum', 'sweet vermouth', 'apple brandy', 'grenadine', 'lemon juice'],
#  ['brandy', 'gin', 'anisette', 'sweet vermouth', 'grenadine'],
#  ['gin', 'orange juice', 'dry vermouth', 'sweet vermouth'],
#  ['gin', 'apricot flavored brandy', 'dry vermouth', 'lemon juice'],
#  ['amaretto', 'white creme de menthe'],
#  ['gin', 'dry vermouth', 'apricot flavored brandy', 'lemon juice'],
#  ['juice of a lime', 'apricot flavored brandy', 'dry vermouth', 'gin'],
#  ['sloe gin', 'gin', 'grenadine'],
#  ['bourbon whiskey',
#   'green creme de menthe',
#   'fresh lime juice',
#   'simple syrup',
#   'fresh mint leaves',
#   'soda water'],
#  ['sweet vermouth', 'dry vermouth', 'gin'],
#  ['gin', 'dry vermouth', 'orange juice'],
#  ['tanqueray gin', 'margarita mix', 'triple sec'],
#  ['amaretto', 'fresh lemon juice', 'simple syrup', 'orange half-wheel'],
#  ['gin', 'sweet vermouth', 'green chartreuse', 'orange bitters'],
#  ['gin', 'triple sec', 'orange juice'],
#  ['sweet vermouth', 'gin', 'bitters'],
#  ['lemon juice', 'green chartreuse', 'gin'],
#  ['gin', 'sweet vermouth', 'dry vermouth'],
#  ['straight rye whiskey',
#   'benedictine',
#   'fresh lemon juice',
#   'honey syrup',
#   'egg white',
#   'angostura bitters'],
#  ['gin', 'orange bitters', 'triple sec'],
#  ['gin', 'dry vermouth', 'grenadine'],
#  ['gin', 'dry vermouth', 'triple sec'],
#  ['sweet vermouth', 'dry vermouth', 'gin', 'bitters', 'orange juice'],
#  ['grenadine', 'gin', 'lemon juice'],
#  ['amaretto', 'fresh lemon juice', 'simple syrup', 'soda water'],
#  ['green chartreuse', 'sweet vermouth', 'gin'],
#  ['irish whiskey', 'ginger ale or soda water', 'lemon twist (optional)'],
#  ['brandy', 'orgeat or almond syrup', 'angostura bitters', 'lemon twist'],
#  ['dry vermouth', 'gin', 'grenadine'],
#  ['juice of a lemon', 'apricot flavored brandy', 'gin'],
#  ['gin', 'dry vermouth', 'orange bitters'],
#  ['amaretto', 'half-and-half'],
#  ['orange', 'pineapple', 'gin', 'sweet vermouth', 'grenadine'],
#  ['sweet vermouth', 'dry vermouth', 'gin'],
#  ['irish whiskey',
#   'triple sec',
#   'anisette',
#   'maraschino liqueur',
#   'angostura bitters',
#   'green olive'],
#  ['absinthe', 'simple syrup', 'orange bitters'],
#  ['gin', 'dry vermouth', 'sweet vermouth', 'bitters'],
#  ['gin', 'anisette'],
#  ['gin', 'white creme de menthe', 'juice of a lemon', 'chilled champagne'],
#  ['irish whiskey',
#   'light rum',
#   'sloe gin',
#   'fresh lemon juice',
#   'simple syrup',
#   'fresh raspberries and strawberries',
#   '2 peach slices',
#   'maraschino cherry'],
#  ['gin', 'lemon juice', 'maraschino'],
#  ['gin', 'dry vermouth', 'sweet vermouth'],
#  ['gin', 'dry vermouth'],
#  ['juice of a lime', 'gin', 'ginger ale'],
#  ['irish whiskey', 'fresh lime juice', 'soda water', 'lime wedge'],
#  ['gin', 'triple sec', 'lemon juice'],
#  ['sweet vermouth', 'gin'],
#  ['gin', 'juice of a lemon', 'ginger ale'],
#  ['juice of a lemon', 'gin', 'ginger ale'],
#  ['rye or bourbon whiskey', 'apple cider', 'apple slice'],
#  ['light vermouth', 'dry vermouth', 'gin', 'bitters'],
#  ['anisette', 'gin', 'dry vermouth', 'creme de menthe (white)'],
#  ['kummel', 'gin', 'apricot flavored brandy', 'lemon juice'],
#  ['bourbon or rye whiskey',
#   'light rum',
#   'fresh lemon juice',
#   'simple syrup',
#   'soda water'],
#  ['gin', 'sweet vermouth', 'anisette'],
#  ['dry vermouth', 'sweet vermouth', 'gin'],
#  ['tennessee whiskey', 'fernet-branca', 'cola'],
#  ['sweet vermouth', 'dry vermouth', 'gin'],
#  ['dry vermouth', 'gin'],
#  ['gin', 'pineapple juice', 'triple sec'],
#  ['vodka', 'coffee liqueur', 'milk or half-and-half'],
#  ['gin', 'grapefruit juice'],
#  ['gin', 'green creme de menthe', 'lime juice'],
#  ['gin', 'green creme de menthe', 'lemon juice'],
#  ['grapefruit juice', 'gin', 'maraschino'],
#  ['fresh rosemary sprig', 'irish whiskey', 'benedictine', 'triple sec'],
#  ['brandy', 'triple sec', 'lemon or orange sherbet'],
#  ['powdered sugar', 'water', 'juice of a lemon', 'gin'],
#  ['powdered sugar', 'gin', 'milk'],
#  ['wide spiral of lemon zest', 'bourbon whiskey', 'ginger ale'],
#  ['gin', 'sweet vermouth'],
#  ['gin', 'bitters'],
#  ['lemon-flavored vodka',
#   'fresh lemon juice',
#   'simple syrup',
#   'fresh mint leaves'],
#  ['lime juice', 'powdered sugar', 'gin'],
#  ['juice of a lemon',
#   'powdered sugar',
#   'gin',
#   'dark rum',
#   'milk',
#   'club soda'],
#  ['gin',
#   'dry vermouth',
#   'apricot flavored brandy',
#   'triple sec',
#   'juice of a lime',
#   'gin & ginger ale'],
#  ['juice of a lime', 'gin & ginger ale', 'gin', 'triple sec'],
#  ['gin', 'triple sec'],
#  ['blended scotch whiskey', 'sweet vermouth', 'benedictine', 'lemon twist'],
#  ['gin', 'dry vermouth'],
#  ['apricot flavored brandy', 'dry vermouth', 'gin', 'lemon juice'],
#  ['gin', 'dry vermouth', 'sweet vermouth', 'bitters'],
#  ['vodka', 'blackberry-flavored brandy', 'dry vermouth', 'fresh lemon juice'],
#  ['gin', 'green creme de menthe', 'bitters'],
#  ['bitters', 'dry vermouth', 'anisette', 'gin'],
#  ['gin', 'dry vermouth'],
#  ['juice of orange', 'anisette', 'dry vermouth', 'gin'],
#  ['orange bitters', 'dry vermouth', 'gin'],
#  ['blended scotch whiskey',
#   'dry vermouth',
#   'fresh lemon juice',
#   'orange bitters'],
#  ['vodka', 'white creme de menthe'],
#  ['gin', 'dry vermouth', 'green creme de menthe'],
#  ['juice of orange', 'gin', 'ginger ale'],
#  ['gin', 'light rum', 'dry vermouth'],
#  ['gin', 'dry vermouth', 'juice of a lime'],
#  ['gin', 'dry vermouth', 'juice of orange'],
#  ['white whiskey', 'grand marnier', 'dry sherry', 'lavender syrup'],
#  ['gin', 'juice of lemon or lime', 'maraschino', 'blue curacao'],
#  ['gin', 'grapefruit juice', 'blue curacao'],
#  ['gin', 'triple sec', 'bitters'],
#  ['dry vermouth', 'sweet vermouth', 'gin'],
#  ['juice of a lime', 'gin', 'club soda'],
#  ['gin', 'green chartreuse', 'sweet vermouth', 'orange bitters'],
#  ['gin', 'apricot flavored brandy', 'grenadine'],
#  ['vodka', 'vodka', 'fresh lemon juice', 'simple syrup'],
#  ['gin', 'apricot flavored brandy', 'anisette', 'lemon juice'],
#  ['dry gin', 'green creme de menthe', 'light cream'],
#  ['blended scotch whiskey',
#   'simple syrup',
#   'soda water or ginger ale',
#   'lemon and/or orange zest spiral(s)'],
#  ['gin', 'creme de cacao (white)', 'light cream'],
#  ['forbidden fruit', 'gin', 'brandy', 'lemon juice'],
#  ['vodka', 'fresh lemon juice', 'simple syrup', 'orange twist'],
#  ['applejack', 'fresh lime juice', 'grenadine'],
#  ['port', 'apricot flavored brandy'],
#  ['apple brandy', 'brandy', 'anisette'],
#  ['vodka', 'green creme de menthe', 'white creme de cacao', 'half-and-half'],
#  ['juice of a lemon',
#   'powdered sugar',
#   'gin',
#   'club soda',
#   'cherry-flavored brandy'],
#  ['brandy', 'bitters', 'lemon juice', 'pineapple juice', 'maraschino'],
#  ['straight rye whiskey',
#   "pimm's no. 1 cup",
#   'dubonnet rouge',
#   'peach bitters'],
#  ['brandy', 'blackberry-flavored brandy', 'dry sherry', 'lemon juice'],
#  ['vodka', 'fresh lime juice', 'simple syrup'],
#  ['maraschino', 'cherry-flavored brandy'],
#  ['brandy', 'apple brandy', 'apricot flavored brandy'],
#  ['coffee-flavored brandy', 'creme de cacao (white)', 'light cream'],
#  ['single-malt scotch whisky',
#   'maraschino liqueur',
#   'triple sec',
#   'apple juice',
#   'fresh lemon juice',
#   'angostura bitters'],
#  ['hennessy v.s cognac', 'lemon juice'],
#  ['vodka', 'fresh lemon juice', 'simple syrup', 'grenadine'],
#  ['single-malt scotch whisky',
#   'pedro ximenez sherry',
#   'fresh lemon juice',
#   'honey syrup'],
#  ['juice of a lemon', 'curacao', 'maraschino', 'brandy'],
#  ['cherry-flavored brandy', 'juice of a lemon'],
#  ['juice of a lemon', 'cherry-flavored brandy', 'club soda'],
#  ['vodka',
#   'simple syrup',
#   'soda water or ginger ale',
#   'orange and/or lemon zest spiral'],
#  ['brandy', 'sweet vermouth'],
#  ['creme de menthe (white)', 'apricot flavored brandy', 'anisette', 'brandy'],
#  ['brandy', 'hard cider'],
#  ['brandy', 'gin', 'dry vermouth'],
#  ['blended scotch whiskey', 'fresh lemon juice', 'agave nectar', 'absinthe'],
#  ['brandy', 'powdered sugar', 'grenadine', 'club soda'],
#  ['brandy', 'club soda'],
#  ['powdered sugar', 'brandy', 'milk'],
#  ['vodka', 'fresh lemon juice', 'simple syrup', 'soda water'],
#  ['maraschino', 'bitters', 'lemon juice', 'triple sec', 'brandy'],
#  ['blended scotch whiskey',
#   'strawberry liqueur',
#   'chilled sparkling wine',
#   'whole strawberry'],
#  ['applejack',
#   'maple syrup (grade b or medium-amber)',
#   'aromatic bitters',
#   'cinnamon stick'],
#  ['creme de cacao (brown)', 'brandy', 'heavy cream'],
#  ['vodka', 'tonic water', 'lemon or lime wedge'],
#  ['juice of a lemon', 'juice of orange', 'apricot flavored brandy', 'gin'],
#  ['creme de cacao (white)', 'brandy', 'light cream'],
#  ['apricot flavored brandy', 'triple sec', 'juice of a lime'],
#  ['straight rye whiskey',
#   'lillet blanc',
#   'apple brandy',
#   'green chartreuse',
#   'angostura bitters',
#   'orange twist'],
#  ['bourbon', 'triple sec', 'lemon juice', 'grenadine'],
#  ['vodka', 'apple juice'],
#  ['springs mint', 'powdered sugar', 'water', 'bourbon'],
#  ['bourbon', 'collins mix', 'lime juice'],
#  ['straight rye whiskey', 'kirschwasser', 'cynar', 'amaro'],
#  ['bourbon', 'brandy', 'creme de menthe', 'club soda'],
#  ['powdered sugar', 'bourbon'],
#  ['vodka', 'unsweetened grape juice', 'fresh lemon juice', 'simple syrup'],
#  ['bourbon', 'cold water'],
#  ['bourbon'],
#  ['bourbon', 'lemon juice', 'grapefruit juice', 'almond extract'],
#  ['bourbon', 'water'],
#  ['straight rye whiskey',
#   'yellow chartreuse',
#   'sweet vermouth',
#   'angostura bitters',
#   'orange bitters',
#   'lemon twist'],
#  ['pineapple juice', 'orange juice', 'lemon juice'],
#  ['vodka', 'peach schnapps', 'simple syrup', 'fresh lemon juice'],
#  ['bourbon whiskey',
#   'applejack',
#   'sweet vermouth',
#   'angostura bitters',
#   "peychaud's bitters",
#   'maraschino cherry'],
#  ['bourbon whiskey', 'fresh lemon juice', 'honey syrup'],
#  ['sake', 'mr. boston gin'],
#  ['blended scotch whiskey', 'amaretto'],
#  ['applejack', 'pineapple juice', 'angostura bitters'],
#  ['amaretto di saronno', 'mr. boston five star brandy', 'light cream'],
#  ['amaretto di saronno', 'coconut milk', 'crushed pineapple'],
#  ['amaretto di saronno'],
#  ['amaretto di saronno', 'roses lime juice', 'club soda'],
#  ['blended scotch whiskey',
#   'pear brandy',
#   'grapefruit juice',
#   'amaro',
#   'grapefruit bitters',
#   'lemon twist'],
#  ['bourbon or rye whiskey',
#   'fresh lemon juice',
#   'fresh lime juice',
#   'benedictine',
#   'lemon and lime wheels'],
#  ['straight rye whiskey',
#   'sweet vermouth',
#   'yellow chartreuse',
#   'fernet-branca'],
#  ['bourbon whiskey',
#   'coffee liqueur',
#   'fresh lemon juice',
#   'orgeat or almond syrup',
#   'orange bitters',
#   'lemon twist'],
#  ['bourbon or rye whiskey', 'dark creme de cacao', 'angostura bitters'],
#  ['blended scotch whiskey',
#   'sweet vermouth',
#   'angostura bitters',
#   'simple syrup'],
#  ['straight rye whiskey',
#   'maraschino liqueur',
#   'green chartreuse',
#   'fresh lemon juice'],
#  ['mr. boston gin', 'dry vermouth'],
#  ['bourbon or rye whiskey',
#   'angostura bitters',
#   'triple sec',
#   'simple syrup',
#   'lemon twist'],
#  ['mandarine napoleon liqueur', 'lemon juice'],
#  ['mandarine napoleon liqueur'],
#  ['lime wedge',
#   'sweet chili powder',
#   'mango-flavored vodka',
#   'peach liqueur',
#   'fresh lime juice',
#   'simple syrup',
#   'ginger ale'],
#  ['bourbon whiskey',
#   'maraschino liqueur',
#   'angostura bitters',
#   'orange bitters'],
#  ['apple brandy', 'benedictine', 'fresh lemon juice', 'triple sec'],
#  ['vodka', 'fresh lime juice', 'lime wedge', 'lemon-lime soda'],
#  ['irish whiskey', 'green creme de menthe', 'green chartreuse', 'green olive'],
#  ['aquavit or vodka', 'cynar', 'dry sherry', 'peach bitters'],
#  ['vodka', 'creme de baa', 'orange juice'],
#  ['fresh strawberries',
#   'cut in halves',
#   'bourbon whiskey',
#   'vanilla liqueur',
#   'triple sec'],
#  ['straight rye whiskey',
#   'fresh grapefruit juice',
#   'maple syrup',
#   'grapefruit twist'],
#  ['lemon wedge',
#   'cinnamon sugar',
#   'citrus-flavored vodka',
#   'limoncello',
#   'amaretto',
#   'fresh lemon juice',
#   'egg white'],
#  ['bourbon whiskey',
#   'orange juice',
#   'fresh lime juice',
#   'orgeat or almond syrup',
#   'simple syrup',
#   'orange and lime wheels'],
#  ['kummel',
#   'mr. boston gin',
#   'mr. boston apricot flavored brandy',
#   'lemon juice'],
#  ['single-malt scotch whisky',
#   'cherry heering',
#   'punt e mes',
#   'orange bitters'],
#  ['blended scotch whiskey',
#   'port',
#   'demerara syrup',
#   'almond milk',
#   'whole egg',
#   'freshly grated nutmeg'],
#  ['apple brandy',
#   'simple syrup',
#   'soda water or ginger ale',
#   'orange and/or lemon zest spiral'],
#  ['straight rye whiskey',
#   'dubonnet rouge',
#   'fernet-branca',
#   'elderflower liqueur'],
#  ['mr. boston triple sec',
#   'absinthe substitute',
#   'maraschino',
#   'bitters',
#   'irish whiskey'],
#  ['irish whiskey', 'sweet vermouth', 'grand marnier', 'orange bitters'],
#  ['rye or bourbon whiskey',
#   'gin',
#   'fresh lemon juice',
#   'white creme de menthe',
#   'grenadine',
#   'simple syrup'],
#  ['bourbon whiskey',
#   'white creme de menthe',
#   'triple sec',
#   'simple syrup',
#   'angostura bitters'],
#  ['georgia moon corn whiskey', 'mountain dew'],
#  ['orange-flavored vodka',
#   'grand marnier',
#   'passion fruit juice',
#   'fresh lime juice',
#   'pomegranate syrup',
#   'fresh raspberry'],
#  ['fresh cilantro leaves',
#   'slice peeled fresh ginger',
#   'citrus-flavored vodka',
#   'limoncello',
#   'pineapple juice'],
#  ['juice of a lime', 'grenadine'],
#  ['citrus-flavored vodka',
#   'mint syrup',
#   'fresh lemon juice',
#   'thyme sprig',
#   'bitter lemon soda',
#   'long thyme sprigs'],
#  ['dubonnet rouge', 'orange-flavored vodka', 'orange bitters', 'lemon twist'],
#  ['amaretto di saronno', 'mr. boston vodka', 'heavy cream'],
#  ['vodka', 'amaretto', 'half-and-half'],
#  ['absinthe', 'straight rye whiskey', 'sweet vermouth', 'maraschino liqueur'],
#  ['brandy',
#   'sweet vermouth',
#   'fresh lemon juice',
#   'grenadine',
#   'angostura bitters'],
#  ['powdered sugar', 'mr. boston gin', 'milk'],
#  ['vodka',
#   'sweet vermouth',
#   'fresh orange juice',
#   'fresh lemon juice',
#   'grenadine',
#   'orange half-wheel',
#   'maraschino cherry'],
#  ['bourbon whiskey', 'fresh lemon juice', 'simple syrup', 'fresh mint leaf'],
#  ['hot tea', 'amaretto di saronno', 'whipped cream'],
#  ['orange-flavored vodka',
#   'rose water',
#   'lillet blanc',
#   'black raspberry liqueur'],
#  ['straight rye whiskey',
#   'mezcal',
#   'amaro',
#   'aperol',
#   'elderflower liqueur',
#   'orange twist',
#   'flamed'],
#  ['straight rye whiskey', 'dubonnet rouge', 'triple sec', 'angostura bitters'],
#  ['old thompson blended whiskey', 'absinthe substitute'],
#  ['citrus-flavored vodka', 'sloe gin', 'simple syrup', 'fresh lemon juice'],
#  ['bourbon whiskey', 'benedictine', 'angostura bitters', 'lemon twist'],
#  ['lemon wedge',
#   'superfine sugar',
#   'citrus-flavored vodka',
#   'simple syrup',
#   'fresh lemon juice',
#   'chilled champagne'],
#  ['straight rye whiskey',
#   'dry vermouth',
#   'white creme de menthe',
#   'fresh lemon juice'],
#  ['vodka', 'peach schnapps', 'fresh orange juice', 'half-and-half'],
#  ['absinthe or pastis', 'brandy', 'peach bitters', 'lemon twist'],
#  ['straight rye whiskey',
#   'sweet vermouth',
#   'benedictine',
#   'absinthe or pastis',
#   "peychaud's bitters",
#   'maraschino cherry'],
#  ['single-malt scotch whisky', 'ginger liqueur', 'lemon twist'],
#  ['vodka', 'amontillado sherry', 'dry vermouth', 'lemon twist'],
#  ['tennessee whiskey',
#   'fresh lemon juice',
#   'simple syrup',
#   'triple sec',
#   'orange and lemon wheels'],
#  ['vodka',
#   'light rum',
#   'creme de baa',
#   'pineapple juice',
#   'orange juice',
#   'cranberry juice'],
#  ['bourbon whiskey', 'madeira', 'grenadine', 'maraschino cherry'],
#  ['powdered sugar', 'carbonated water', 'mr. boston rum', 'ginger ale'],
#  ['vodka', 'white creme de cacao', 'white creme de menthe', 'half-and-half'],
#  ['vanilla-infused bourbon',
#   'honey-currant syrup',
#   'fresh lime juice',
#   'egg white',
#   'rhubarb bitters',
#   'stick of cotton candy'],
#  ['apple brandy',
#   'apricot-flavored brandy',
#   'gin',
#   'fresh orange juice',
#   'grenadine'],
#  ['cognac',
#   'triple sec',
#   'fresh lemon juice',
#   'vodka',
#   'madeira',
#   'fresh orange juice and orange wheel'],
#  ['vodka',
#   'madeira',
#   'fresh orange juice and orange wheel',
#   'bourbon whiskey',
#   'white creme de cacao',
#   'fresh lemon juice'],
#  ['bourbon whiskey', 'white creme de cacao', 'fresh lemon juice', 'grenadine'],
#  ['vodka', 'cranberry juice', 'fresh grapefruit juice', 'lime wedge'],
#  ['vodka', 'orange juice'],
#  ['bourbon whiskey',
#   'simple syrup',
#   'angostura bitters',
#   'cold brewed coffee',
#   'soda water',
#   'orange wheel',
#   'maraschino cherry'],
#  ['mr. boston gin', 'dry vermouth'],
#  ['lemon wedge', 'coarse salt', 'vodka', 'grapefruit juice'],
#  ['mr. boston gin', 'lemon juice', 'maraschino', 'egg white'],
#  ['mr. boston gin', 'dry vermouth'],
#  ['bourbon whiskey',
#   'tawny port',
#   'fresh lemon juice',
#   'vanilla liqueur and 3 oz',
#   'simple syrup',
#   'whole egg and grated nutmet'],
#  ['bourbon whiskey', 'fresh lime juice', 'blackberry liqueur', 'b & b'],
#  ['vodka',
#   'orange liqueur',
#   'canned coconut milk',
#   'cold brewed chai tea',
#   'orgeat or almond syrup',
#   'pineapple wedge'],
#  ['bourbon whiskey',
#   'amaretto',
#   'benedictine',
#   'triple sec',
#   'orange curacao',
#   'orange twist'],
#  ['brandy',
#   'kirschwasser',
#   'half-and-half',
#   'orgeat or almond syrup',
#   'absinthe or pastis'],
#  ['vodka', 'white creme de cacao', 'half-and-half'],
#  ['scotch whiskey', 'coconut liqueur', 'dry sherry', 'grapefruit bitters'],
#  ['grapefruit-flavored vodka',
#   'triple sec',
#   'fresh ruby red grapefruit juice',
#   'fresh orange juice'],
#  ['bourbon whiskey',
#   'dry sherry',
#   'ramazzotti amaro',
#   'triple sec',
#   'orange bitters',
#   'lemon twist'],
#  ['for glass lemon wedge',
#   'coarse salt',
#   'grapefruit-flavored vodka',
#   'fresh lemon juice',
#   'grapefruit juice',
#   'campari',
#   'simple syrup'],
#  ['clementine or mandarin orange',
#   'vodka',
#   'fresh lemon juice',
#   'honey syrup',
#   'fresh rosemary sprig',
#   'chilled sparkling wine or champagne'],
#  ['bourbon whiskey', 'triple sec', 'fresh lemon juice', 'orange twist'],
#  ['vodka', 'cranberry juice', 'white creme de cacao'],
#  ['blended scotch whiskey',
#   'dry vermouth',
#   'tawny port',
#   "peychaud's bitters"],
#  ['amaretto di saronno', 'hot black coffee'],
#  ['straight rye whiskey',
#   'cognac',
#   'sweet vermouth',
#   'elderflower liqueur',
#   'angostura bitters',
#   "peychaud's bitters"],
#  ['cherry-flavored brandy',
#   'gin',
#   'dry vermouth',
#   'fresh lemon juice',
#   'orange bitters'],
#  ['strawberries',
#   'cut into halves',
#   'fresh lemon juice',
#   'simple syrup',
#   'citrus-flavored vodka',
#   "chilled moscato d'asti or sweet sparkling wine",
#   'strawberry'],
#  ['vodka', 'apple juice', 'fresh lemon juice', 'grenadine'],
#  ['blended scotch whiskey',
#   'orange juice',
#   'fresh lemon juice',
#   'soda water',
#   'orange wheel'],
#  ['canadian whisky', 'triple sec', 'simple syrup', 'angostura bitters'],
#  ['vodka',
#   'pomegranate juice',
#   'grapefruit juice',
#   'fresh lime juice',
#   'honey syrup',
#   'grapefruit twist'],
#  ['maraschino liqueur',
#   'canadian whisky',
#   'maraschino liqueur',
#   'fresh lemon juice',
#   'orange juice'],
#  ['egg', 'juice of orange', 'grenadine'],
#  ['vodka',
#   'light rum',
#   'gin',
#   'black raspberry liqueur',
#   'simple syrup',
#   'fresh lemon juice and 3 oz'],
#  ['canadian whisky',
#   'pineapple juice',
#   'fresh lemon juice',
#   'maraschino liqueur',
#   'pineapple wedge',
#   'maraschino cherry'],
#  ['vodka', 'grapefruit juice', 'concord grape juice', 'simple syrup'],
#  ['blended scotch whiskey',
#   'irish whiskey',
#   'fresh lemon juice',
#   'orange bitters'],
#  ['mint sprigs', 'simple syrup', 'brandy', 'peach-flavored brandy'],
#  ['bourbon whiskey',
#   'fresh lemon juice',
#   'fresh lime juice',
#   'simple syrup',
#   'grenadine',
#   'soda water',
#   'orange and lemon wheels',
#   'maraschino cherry'],
#  ['mr. boston five star brandy',
#   'mr. boston rum',
#   'mr. boston triple sec',
#   'juice of a lime'],
#  ['bourbon whiskey', 'fresh lemon juice', 'simple syrup', 'ginger ale'],
#  ['bourbon whiskey', 'orange curacao', 'fresh lemon juice', 'grenadine'],
#  ['rye or bourbon whiskey',
#   'sweet vermouth',
#   'amer picon or torani amer',
#   'maraschino liqueur'],
#  ['bourbon whiskey',
#   'brandy',
#   'benedictine',
#   'orange juice',
#   'fresh lemon juice',
#   'soda water',
#   'orange and lemon wheels'],
#  ['bourbon whiskey',
#   'fresh lemon juice',
#   'creme de cassis',
#   'simple syrup',
#   'angostura bitters'],
#  ['bourbon whiskey', 'ginger ale or soda water', 'lemon twist'],
#  ['bourbon whiskey',
#   'elderflower liqueur',
#   'angostura bitters',
#   'lemon twist'],
#  ['lemon wedge',
#   'superfine sugar',
#   'long',
#   'wide spiral of orange zest',
#   'bourbon whiskey',
#   'triple sec',
#   'maraschino liqueur',
#   'fresh lemon juice',
#   'orange bitters'],
#  ['bourbon whiskey', 'fresh lemon juice', 'grapefruit juice', 'orgeat syrup'],
#  ['brandy', 'sweet vermouth', 'benedictine'],
#  ['bourbon whiskey', 'dark creme de cacao', 'vanilla liqueur'],
#  ['bourbon whiskey',
#   'fresh lime juice',
#   'simple syrup',
#   'hot red pepper sauce'],
#  ['blended scotch whiskey', 'sweet vermouth', 'benedictine', 'lemon twist'],
#  ['smoky scotch whisky',
#   'such as laphroaig',
#   'tomato juice',
#   'v8 cocktail juice',
#   'ketchup',
#   'fresh lime juice',
#   'simple syrup',
#   '3/4 oz'],
#  ['vanilla ice cream', 'mr. boston gin'],
#  ['blended scotch whiskey',
#   'cherry-flavored brandy',
#   'sweet vermouth',
#   'orange juice'],
#  ['straight rye whisky',
#   'grapefruit juice',
#   'raspberry syrup',
#   'grapefruit twist or skewered raspberry'],
#  ['cider', 'juice of a lemon', 'powdered sugar', 'whole egg'],
#  ['irish whiskey',
#   'anisette',
#   'triple sec',
#   'maraschino liqueur',
#   'angostura bitters',
#   'orange twist',
#   'green olive'],
#  ['lemon juice', 'grenadine', 'bitters', 'ginger ale'],
#  ['juice of a lemon', 'powdered sugar', 'egg yolk', 'water'],
#  ['bourbon whiskey', 'sloe gin', 'maraschino cherry'],
#  ['juice of a lemon', 'powdered sugar', 'whole egg'],
#  ['cynar', 'straight rye whiskey', 'dry vermouth', 'maraschino liqueur'],
#  ['juice of a lemon', 'powdered sugar', 'grenadine', 'brandy', 'port'],
#  ['irish whiskey', 'rhubarb syrup', 'cold brewed green tea', 'edible flowers'],
#  ['brandy', 'lillet blanc', 'lemon quarter-wheel'],
#  ['gin', 'white creme de menthe', 'egg white', 'lemon juice', 'orange juice'],
#  ['vodka', 'egg yolk', 'orange juice', 'sugar'],
#  ['orange juice', 'cream sherry', 'brandy', 'light cream'],
#  ['vanilla liqueur', 'milk', 'orange juice'],
#  ['blended whiskey', 'light cream'],
#  ['blended scotch whiskey', 'dry vermouth', 'sweet vermouth'],
#  ['gin', 'dubonnet', 'dry vermouth'],
#  ['lemon juice', 'maraschino', 'egg white', 'gin'],
#  ['dry vermouth', 'brandy', 'triple sec', 'powdered sugar', 'bitters'],
#  ['bourbon whiskey', 'triple sec', 'fresh lemon juice'],
#  ['raspberry yogurt',
#   'raspberry ice cream',
#   'white creme de cacao',
#   'vodka',
#   'heavy cream'],
#  ['cognac', 'tawny port', 'anis', 'lemon juice'],
#  ['coffee-flavored brandy', 'lemon juice', 'powdered sugar', 'egg white'],
#  ['whole egg', 'powdered sugar', 'brandy', 'port', 'light cream (if desired)'],
#  ['whole egg', 'powdered sugar', 'port', 'brandy'],
#  ['vodka', 'concord grape juice', 'white creme de cacao'],
#  ['sweet vermouth', 'sloe gin', 'muscatel wine'],
#  ['juice of a lime', 'grenadine', 'egg white', 'gin'],
#  ['juice of a lemon', 'grenadine', 'egg white', 'gin'],
#  ['vodka', 'calvados', 'coffee liqueur', 'lemon twist'],
#  ['vodka', 'clam juice', 'tomato juice'],
#  ['whole egg', 'powdered sugar', 'milk'],
#  ['juice of a lime', 'dubonnet', 'gin'],
#  ['whole egg',
#   'powdered sugar',
#   'sloe gin',
#   'brandy',
#   'light cream (if desired)'],
#  ['port', 'yellow chartreuse', 'egg yolk', 'powdered sugar'],
#  ['juice of a lemon', 'powdered sugar', 'egg white', 'port', 'light rum'],
#  ['vodka', 'cranberry juice', 'creme de noyaux', 'fresh lemon juice'],
#  ['danish cherry wine', 'vodka', 'juice of a lime'],
#  ['whole egg',
#   'powdered sugar',
#   'cherry-flavored brandy',
#   'light cream (if desired)'],
#  ['cherry vodka', 'cola'],
#  ['lime wedge',
#   'superfine sugar',
#   'vodka',
#   'cherry-flavored brandy',
#   'fresh lime juice'],
#  ['dark rum', 'sugar', 'bitters', 'milk'],
#  ['chilled stout', 'chilled champagne'],
#  ['vodka', 'pineapple or grapefruit juice', 'grenadine'],
#  ['bourbon whiskey',
#   'dry vermouth',
#   'pineapple juice',
#   'ginger beer',
#   'fresh mint sprig'],
#  ['canadian whisky', 'pineapple juice', 'lemon juice', 'maraschino'],
#  ['strega', 'light rum', 'passion fruit syrup', 'lemon juice', 'egg white'],
#  ['citrus-flavored vodka',
#   'triple sec',
#   'fresh lime juice',
#   'fresh lemon juice',
#   'simple syrup',
#   'cranberry juice',
#   'lemon wheel'],
#  ['creme de cacao (brown)', 'brandy', 'milk', 'egg yolk'],
#  ['hot black coffee', 'amaretto', 'whipped cream'],
#  ['egg white', 'anis', 'light cream', 'gin'],
#  ['bourbon whiskey',
#   'white creme de cacao',
#   'benedictine',
#   'hot red pepper sauce'],
#  ['brandy', 'anisette', 'dry vermouth'],
#  ['hot shot tropical fruit liqueur', 'orange juice'],
#  ['hot shot tropical fruit liqueur', 'grapefruit juice'],
#  ['anisette', 'egg white'],
#  ['strawberry schnapps', 'grenadine'],
#  ['straight rye whiskey',
#   'apple brandy',
#   'sweet vermouth',
#   'strega',
#   'angostura bitters',
#   'orange twist'],
#  ['vodka', 'aquavit', 'dill pickle brine', 'angostura bitters'],
#  ['blended scotch whiskey', 'cherry-flavored brandy', 'cranberry juice'],
#  ['orange juice', 'dubonnet', 'dry vermouth', 'bourbon'],
#  ['vodka', 'dry vermouth', 'sweet pickle brine', 'sweet pickle slice'],
#  ['whole egg', 'powdered sugar', 'sloe gin', 'light cream (if desired)'],
#  ['bourbon whiskey', 'amaro', 'creme de cassis', 'orange bitters'],
#  ['vanilla ice cream', 'gin', 'carbonated water'],
#  ['egg white', 'juice of a lemon', 'gin', 'powdered sugar', 'orange bitters'],
#  ['brown sugar cube',
#   'such as demerara',
#   'straight rye whiskey',
#   'applejack',
#   'orange twist'],
#  ['juice of a lemon', 'powdered sugar', 'gin', 'egg white'],
#  ['cream sherry', 'brandy', 'dry vermouth', 'triple sec', 'lemon juice'],
#  ['powdered sugar', 'water', 'cream sherry', 'carbonated water', 'port'],
#  ['powdered sugar', 'cream sherry'],
#  ['vodka', 'triple sec', 'sweet vermouth', 'orange juice'],
#  ['whole egg', 'powdered sugar', 'cream sherry', 'light cream (if desired)'],
#  ['cream sherry'],
#  ['tennessee whiskey',
#   'simple syrup',
#   'angostura bitters',
#   'chilled american sparkling wine'],
#  ['bourbon whiskey',
#   'dry vermouth',
#   'blackberry-flavored brandy',
#   'fresh lemon juice'],
#  ['powdered sugar', 'whole egg', 'port', 'light rum'],
#  ['egg white', 'light rum', 'juice of a lime', 'grenadine'],
#  ['peach-flavored vodka',
#   'orange curacao',
#   'fresh lemon juice',
#   'honey syrup',
#   'iced tea',
#   'peach slice',
#   'lemon wheel'],
#  ['brandy', 'dry vermouth', 'white creme de menthe', 'maraschino liqueur'],
#  ['scotch', 'egg yolk', 'triple sec', 'powdered sugar', 'light cream'],
#  ['straight rye whiskey', 'dry vermouth', 'pineapple juice'],
#  ['juice of orange', 'gin', 'white creme de cacao', 'egg white'],
#  ['juice of a lemon', 'powdered sugar', 'egg white', 'light cream', 'gin'],
#  ['vodka', 'white creme de cacao', 'fresh lemon juice'],
#  ['brandy', 'worcestershire sauce', 'catsup', 'vinegar', 'pepper'],
#  ['gin', 'whole egg', 'pepper and salt'],
#  ['maraschino', 'egg yolk', 'benedictine', 'brandy'],
#  ['applejack', 'light rum', 'lime juice', 'orgeat syrup'],
#  ['straight rye whiskey',
#   'ginger syrup',
#   'cold brewed black tea',
#   'preferably japanese',
#   'fresh lemon juice'],
#  ['tequila', 'lemon juice', 'maraschino', 'egg white', 'grenadine'],
#  ['whole egg', 'powdered sugar', 'port', 'light cream (if desired)'],
#  ['powdered sugar', 'carbonated water', 'shaved ice', 'port'],
#  ['vodka', 'peach schnapps', 'peach puree', 'fresh lemon juice'],
#  ['blended scotch whiskey',
#   'dry vermouth',
#   'sweet vermouth',
#   'orange bitters'],
#  ['dry vermouth', 'sweet vermouth', 'orange bitters'],
#  ['juice of a lemon', 'egg white', 'sloe gin'],
#  ['vodka', 'fresh lime juice', 'ginger beer', 'lime wedge'],
#  ['dubonnet', 'brandy', 'anis'],
#  ['straight rye whiskey',
#   'maraschino liqueur',
#   'fresh lemon juice',
#   'orange bitters'],
#  ['dry vermouth', 'gin', 'anis', 'dubonnet'],
#  ['juice of a lemon', 'powdered sugar', 'light cream', 'gin', 'peach'],
#  ['lemon juice', 'powdered sugar', 'gin', 'peach'],
#  ['chilled passion fruit juice', 'chilled champagne'],
#  ['vodka',
#   'irish cream liqueur',
#   'coffee liqueur',
#   'cold brewed espresso coffee'],
#  ['blended whiskey', 'bitters', 'lemon juice'],
#  ['vodka',
#   'elderflower liqueur',
#   'fresh lemon juice',
#   'simple syrup',
#   'aperol',
#   'orange twist'],
#  ['egg white',
#   'lemon juice',
#   'dry vermouth',
#   'sweet vermouth',
#   'blended whiskey'],
#  ['juice of a lemon', 'powdered sugar', 'egg white', 'anis', 'scotch'],
#  ['straight rye whiskey',
#   'maraschino liqueur',
#   'orange bitters',
#   'fresh lemon juice'],
#  ['brandy', 'triple sec', 'simple syrup', 'angostura bitters'],
#  ['gin', 'lemon juice', 'egg white', 'powdered sugar'],
#  ['tequila', 'madeira', 'egg yolk', 'crushed ice'],
#  ['vanilla-flavored vodka',
#   'fresh lemon juice',
#   'butterscotch schnapps',
#   'limoncello'],
#  ['mint-flavored gin', 'white port wine', 'dry vermouth'],
#  ['juice of a lemon', 'mint-flavored gin'],
#  ['pineapple juice', 'grenadine', 'egg white', 'sweet vermouth', 'gin'],
#  ['egg white', 'grenadine', 'triple sec', 'blended whiskey'],
#  ['irish whiskey',
#   'applejack',
#   'amaro nonino',
#   'rye whiskey',
#   'demerara syrup',
#   'mole bitters 1 oz'],
#  ['powdered sugar', 'blended whiskey', 'milk'],
#  ['juice of orange',
#   'juice of a lemon',
#   'egg white',
#   'powdered sugar',
#   'sloe gin'],
#  ['grenadine', 'juice of a lemon', 'swedish punch'],
#  ['dubonnet', 'dry vermouth'],
#  ['bourbon whiskey',
#   'fresh lemon juice',
#   'white creme de cacao',
#   'lillet rouge'],
#  ['gin', 'whole egg', 'powdered sugar', 'root beer', 'juice of a lime'],
#  ['bourbon whiskey',
#   'gingerbread liqueur',
#   'cherry-flavored brandy',
#   'angostura bitters',
#   'italian preserved cherry'],
#  ['fresh basil leaves',
#   'vodka',
#   'green chartreuse',
#   'fresh lime juice',
#   'simple syrup',
#   'passion fruit juice',
#   'basil leaf'],
#  ['vodka', 'cranberry juice', 'orange juice', 'lime wedge'],
#  ['absinthe substitute', 'water', 'old mr. boston anisette', 'orange bitters'],
#  ['vodka',
#   'lychee liqueur',
#   'fresh orange juice',
#   'pineapple juice',
#   'angostura bitters',
#   'canned pitted lychee nut stuffed with a small pineapple leaf'],
#  ['mr. boston vodka', 'dry vermouth'],
#  ['black cherry-flavored vodka',
#   'white creme de cacao',
#   'chile syrup',
#   'grated bittersweet chocolate'],
#  ['vodka',
#   'blanco tequila',
#   'gin',
#   'light rum',
#   'triple sec',
#   'simple syrup',
#   '1/2 oz'],
#  ['calvados', 'sweet vermouth', 'dry vermouth', 'brandy'],
#  ['vodka', 'lillet blanc', 'ramazzotti amaro', 'orange bitters'],
#  ['light rum', 'dubonnet', 'lemon juice'],
#  ['juice of a lemon', 'powdered sugar', 'egg white', 'grenadine', 'sloe gin'],
#  ['citrus-flavored vodka',
#   'limoncello',
#   'manzanilla sherry',
#   'fresh lemon juice',
#   'grapefruit marmalade',
#   'orange twist'],
#  ['red wine', 'ginger ale', 'lemon', 'whole cloves'],
#  ['juice of a lemon', 'powdered sugar', 'gin', 'whole egg'],
#  ['whole egg', 'juice of a lemon', 'powdered sugar', 'gin'],
#  ['juice of a lime', 'grenadine', 'egg yolk', 'gin'],
#  ['cucumber slices',
#   'chopped',
#   'fresh lemon juice',
#   'simple syrup',
#   'acai berry flavored vodka',
#   'black raspberry liqueur',
#   'sparkling wine',
#   'raspberry and cucumber'],
#  ['cherry vodka', 'orange juice', 'triple sec'],
#  ['rock and rye', 'vodka', 'lime juice', 'bitter lemon soda'],
#  ['rock and rye', 'white port wine', 'dry vermouth'],
#  ['vodka', 'raspberry-flavored liqueur', 'grand marnier', 'chilled champagne'],
#  ['juice of a lime',
#   'powdered sugar',
#   'carbonated water',
#   'gin',
#   'bitters',
#   'grenadine'],
#  ['lemon wedge',
#   'superfine sugar',
#   'lemon-flavored vodka',
#   'fresh lemon juice',
#   'simple syrup'],
#  ['bourbon', 'triple sec', 'orange juice', 'lemon juice', 'egg white'],
#  ['blended whiskey', 'egg white', 'lemon juice', 'powdered sugar', 'anis'],
#  ['juice of a lemon',
#   'egg white',
#   'powdered sugar',
#   'gin',
#   'light cream',
#   'triple sec'],
#  ['sloe gin', 'sweet vermouth', 'dry vermouth', 'bitters', 'orange bitters'],
#  ['green chartreuse', 'sweet vermouth', 'gin', 'sake'],
#  ['sake', 'gin'],
#  ['lemon wedge',
#   'superfine sugar',
#   'citrus-flavored vodka',
#   'crema di limoncello',
#   'triple sec',
#   'fresh lemon juice'],
#  ['bitters', 'powdered sugar', 'rye whiskey'],
#  ['aquavit',
#   'old tom gin',
#   'demerara syrup',
#   'orange bitters',
#   'absinthe',
#   'celery stick'],
#  ['benedictine', 'whole egg'],
#  ['whole egg',
#   'powdered sugar',
#   'blended whiskey',
#   'light cream (if desired)'],
#  ['vodka',
#   'creme de baa',
#   'fresh orange juice',
#   'pineapple juice',
#   'dark rum',
#   'lime wheel',
#   'maraschino cherry'],
#  ['gin', 'orange juice', 'juice of a lime', 'maraschino', 'egg white'],
#  ['blended whiskey', 'milk', 'powdered sugar'],
#  ['gin', 'sweet vermouth', 'egg white'],
#  ['powdered sugar', 'water', 'blended whiskey'],
#  ['vodka', 'white creme de cacao', 'fresh lemon juice', 'grenadine'],
#  ['lump of sugar', 'boiling water', 'blended whiskey', 'lemon peel'],
#  ['powdered sugar', 'blended whiskey'],
#  ['cucumber slices',
#   'vodka',
#   'sake',
#   'fresh lime juice',
#   'simple syrup',
#   'cucumber'],
#  ['apricot-flavored brandy', 'white creme de menthe', 'triple sec'],
#  ['light rum', 'fresh lime juice', 'simple syrup'],
#  ['dry vermouth', 'gin', 'apricot-flavored brandy', 'apple brandy'],
#  ['juice of a lime', 'dubonnet', 'brandy', 'maraschino'],
#  ['vodka',
#   'light rum',
#   'triple sec',
#   'each cranberry juice',
#   'orange juice',
#   'pineapple juice',
#   'lemon juice',
#   'simple syrup',
#   'orange wheel',
#   'maraschino cherry'],
#  ['orange juice', 'cherry-flavored brandy', 'gin', 'dubonnet'],
#  ['light rum', 'orange juice', 'mandarine napoleon liqueur'],
#  ['powdered sugar', 'juice of a lemon', 'egg white', 'brandy', 'grenadine'],
#  ['dry vermouth', 'brandy', 'bitters', 'sugar syrup'],
#  ['vodka',
#   'melon liqueur',
#   'creme de baa',
#   'coconut-flavored rum',
#   'half-and-half'],
#  ['gin', 'sweet vermouth', 'grenadine', 'orange juice', 'egg white'],
#  ['lime wedge',
#   'pink sanding sugar',
#   'each citrus-flavored vodka and orange-flavored vodka',
#   'creme de cassis',
#   'apricot nectar',
#   'each fresh lemon juice and cranberry juice',
#   'chilled champagne',
#   'orange half-wheel',
#   'lime wheel'],
#  ['hot shot tropical fruit liqueur', 'hot apple cider'],
#  ['canadian whisky', 'dubonnet', 'triple sec'],
#  ['vodka', 'kummel', 'juice of a lime'],
#  ['lime wedge',
#   'superfine sugar',
#   'citrus-flavored vodka',
#   'orange juice',
#   'grapefruit juice',
#   'ginger ale',
#   'lime wheel'],
#  ['tequila', 'tonic'],
#  ['blended whiskey', 'anis'],
#  ['orange-flavored vodka',
#   'campari',
#   'grapefruit juice',
#   'pomegranate molasses',
#   'peach schnapps',
#   'apple schnapps',
#   'grapefruit twist'],
#  ['powdered sugar', 'egg yolk', 'brandy', 'cayenne pepper'],
#  ['vodka', 'jamaica rum', 'fresh lime juice', 'simple syrup'],
#  ['tequila', 'grenadine', 'lemon juice', 'egg white'],
#  ['vodka', 'orange juice', 'galliano', 'whole egg', "peychaud's bitters"],
#  ['tequila', 'juice of a lemon', 'grenadine', 'egg white'],
#  ['blended whiskey', 'triple sec', 'anis', 'dubonnet'],
#  ['light rum', 'ginger beer'],
#  ['gin',
#   'light rum',
#   'vodka',
#   'hot shot tropical fruit liqueur',
#   '7-up',
#   'each cranberry juice and orange juice'],
#  ['light rum', 'lime liqueur', 'triple sec', 'lime juice'],
#  ['vodka', 'angostura bitters', 'ginger ale'],
#  ['sloe gin', 'egg white', 'lemon juice', 'raspberry juice'],
#  ['juice of a lemon',
#   'powdered sugar',
#   'whole egg',
#   'sweet vermouth',
#   'blended whiskey'],
#  ['vodka', 'gin', 'light rum', 'tequila', 'juice of a lemon'],
#  ['vodka', 'fresh orange juice', 'galliano'],
#  ['lime vodka', 'lemon-lime soda'],
#  ['brandy', 'port', 'apricot-flavored brandy', 'powdered sugar', 'egg yolk'],
#  ['vodka', 'triple sec', 'green chartreuse'],
#  ['pisco', 'punt e mes', 'benedictine', 'aromatic bitters', 'lemon twist'],
#  ['gin', 'orange flavored gin', 'sweet vermouth', 'lemon juice'],
#  ['grape juice', 'swedish punch', 'gin'],
#  ['powdered sugar', 'juice of a lemon', 'egg white', 'gin', 'light cream'],
#  ['vodka', 'soda water', 'orange juice'],
#  ['light rum',
#   'white creme de cacao',
#   'creme de baa',
#   'vanilla ice cream',
#   'half-and-half',
#   'baa'],
#  ['dry vermouth', 'sweet vermouth', 'gin'],
#  ['tequila', 'hot shot tropical fruit liqueur', 'lemon or lime juice'],
#  ['lemon wedges', 'superfine sugar', 'citrus-flavored vodka'],
#  ['whole egg', 'powdered sugar', 'brandy'],
#  ['vodka', 'raspberry-flavored liqueur', 'fresh lemon juice'],
#  ['scotch', 'vermouth', 'lemon juice', 'orange bitters'],
#  ['vodka',
#   'fresh grapefruit juice',
#   'fresh lime juice',
#   'simple syrup',
#   'chilled champagne'],
#  ['100-proof vodka', 'rock and rye', 'lemon juice'],
#  ['vodka', 'amaretto'],
#  ['gin', 'anisette', 'anis'],
#  ['lime vodka', 'lemon-lime soda', 'powdered sugar'],
#  ['powdered sugar',
#   'egg white',
#   'juice of a lemon',
#   'gin',
#   'green creme de menthe'],
#  ['vodka', 'amaretto', 'heavy cream'],
#  ['vodka', 'grape juice', 'egg white', 'lemon juice'],
#  ['brandy', 'grapefruit juice', 'lemon juice', 'honey', 'whole egg'],
#  ['yellow chartreuse', 'apricot-flavored brandy'],
#  ['amaretto', 'sweet vermouth', 'light rum'],
#  ['orange juice', 'lemon juice', 'sugar', 'port'],
#  ['vodka',
#   'peach schnapps',
#   'white rum',
#   'triple sec',
#   'sambuca',
#   'lime soda',
#   'orange wheel',
#   'maraschino cherry'],
#  ['juice of a lemon', 'powdered sugar', 'gin', 'egg yolk'],
#  ['blended whiskey',
#   'brandy',
#   'juice of a lemon',
#   'raspberry syrup',
#   'sugar',
#   'egg white'],
#  ['wine (port',
#   'cream sherry',
#   'claret',
#   'burgundy',
#   'or madeira)',
#   'dried orange peel',
#   'cinnamon sticks',
#   'cloves'],
#  ['vodka', 'peach schnapps', 'grenadine'],
#  ['peach slice',
#   'skinned',
#   'vodka',
#   'fresh lemon juice',
#   'peach bitters',
#   'ginger beer',
#   'peach slice'],
#  ['vodka', 'gin', 'blanco tequila', 'orange wheel', 'maraschino cherry'],
#  ['brandy',
#   'jamaica rum',
#   'triple sec',
#   'pineapple juice',
#   'angostura bitters',
#   'lemon twist',
#   'maraschino cherry'],
#  ['whole egg', 'powdered sugar', 'red wine'],
#  ['vodka',
#   'creme de noyaux',
#   'fresh lemon juice',
#   'pineapple juice',
#   'soda water',
#   'lemon wheel',
#   'pineapple chunk'],
#  ['brandy', 'light rum', 'lemon juice', 'egg yolk', 'powdered sugar'],
#  ['applejack', 'lime juice', 'sugar', 'egg white'],
#  ['vodka', 'sambuca', 'black licorice stick'],
#  ['egg white', 'gin', 'grenadine'],
#  ['vodka', 'black raspberry liqueur', 'pineapple juice'],
#  ['splash triple sec', 'orange-flavored vodka', 'lillet blanc'],
#  ['apricot-flavored brandy', 'dry vermouth', 'lemon juice', 'gin'],
#  ['vodka', 'blue curacao', 'simple syrup', 'fresh lemon juice', 'lime soda'],
#  ['egg white', 'grenadine', 'apricot-flavored brandy', 'gin'],
#  ['triple sec',
#   'orange juice',
#   'lemon juice',
#   'maraschino',
#   'whole egg',
#   'chilled champagne'],
#  ['vodka', 'smoky scotch', 'such as laphroaig', 'pastis'],
#  ['dubonnet', 'ginger ale', 'carbonated water'],
#  ['juice of orange', 'juice of a lemon', 'cherry-flavored brandy', 'dubonnet'],
#  ['dubonnet', 'gin', 'orange bitters (if desired)'],
#  ['gin', 'lemon juice', 'maraschino', 'egg white'],
#  ['vodka', 'fresh orange juice', 'pineapple juice', 'grenadine'],
#  ['gin', 'dry vermouth'],
#  ['lemon juice', 'port', 'dry vermouth'],
#  ['juice of a lemon', 'powdered sugar', 'whole egg', 'scotch', 'triple sec'],
#  ['cucumber slices',
#   'fresh mint leaves',
#   'simple syrup',
#   'vodka',
#   'fresh lime juice',
#   'fresh mint sprig'],
#  ['citrus-flavored vodka',
#   'melon liqueur',
#   'triple sec',
#   'simple syrup',
#   'fresh lemon juice',
#   'lime soda',
#   'pineapple wedge',
#   'maraschino cherry or lime wheel'],
#  ['vodka', 'fresh lime juice', 'triple sec', 'cranberry juice', 'lime wheel'],
#  ['brandy', 'triple sec', 'anisette'],
#  ['gin', 'triple sec', 'anis', 'powdered sugar', 'egg yolk'],
#  ['juice of a lemon',
#   'powdered sugar',
#   'blended whiskey',
#   'port',
#   'egg white'],
#  ['citrus-flavored vodka',
#   'fresh lime juice',
#   'lemonade',
#   'cranberry juice',
#   'lime wedge'],
#  ['egg white', 'lemon juice', 'maraschino', 'gin'],
#  ['bison grass vodka (zubrowka)',
#   'benedictine',
#   'campari',
#   'fresh grapefruit juice',
#   'angostura bitters',
#   'grapefruit twist'],
#  ['juice of a lemon',
#   'juice of a lime',
#   'powdered sugar',
#   'egg white',
#   'gin',
#   'light cream',
#   '1/2 oz'],
#  ['gin', 'curacao', 'dubonnet'],
#  ['gold rum',
#   '151-proof rum',
#   'light rum',
#   'each fresh lime juice',
#   'lemon juice',
#   'pineapple juie',
#   'and passion fruit syrup',
#   'demerara syrup',
#   "tiki (such as bittermen's 'elemakule) or angostura bitters (optional) garnish: fresh mint sprig"],
#  ['sloe gin', 'brandy', 'egg white', 'juice of a lemon'],
#  ['light rum', 'triple sec', 'fresh lemon juice'],
#  ['kummel', 'gin', 'apricot-flavored brandy', 'lemon juice'],
#  ['egg yolk',
#   'powdered sugar',
#   'anis',
#   'triple sec',
#   'white creme de cacao',
#   'light rum'],
#  ['light rum',
#   '151-proof rum',
#   'each vodka',
#   'tequila blanco',
#   'triple sec',
#   'amaretto',
#   'each fresh orange juice',
#   'pineapple juice',
#   'cranberry juice',
#   'orange wheel',
#   'maraschino cherry'],
#  ['egg white',
#   'blended whiskey',
#   'port',
#   'juice of a lemon',
#   'powdered sugar'],
#  ['medium eggs',
#   'sugar',
#   'whole milk',
#   'heavy cream',
#   'whipped',
#   'cognac',
#   'powdered nutmeg'],
#  ['whole egg', 'powdered sugar', 'juice of a lemon', 'brandy', 'triple sec'],
#  ['light rum',
#   'fresh lemon juice',
#   'simple syrup',
#   'grenadine',
#   'angostura bitters'],
#  ['light rum', 'triple sec', 'gin', 'anisette'],
#  ['whole egg', 'maraschino', 'triple sec'],
#  ['peach-flavored brandy', 'lime vodka', 'pineapple juice'],
#  ['maraschino', 'dubonnet', 'gin'],
#  ['ripe pear', 'dark rum', 'benedictine', 'angostura bitters'],
#  ['grenadine', 'sweet vermouth', 'blended whiskey'],
#  ['lime vodka', 'coffee-flavored brandy', 'cream sherry'],
#  ['light rum', 'maple syrup', 'fresh lemon juice'],
#  ['gin', 'dubonnet'],
#  ['peeled and chopped fresh ginger',
#   'fresh lime juice',
#   'each simple syrup',
#   'light rum',
#   'dark rum',
#   'mango juice',
#   'each cranberry juice',
#   'orange juice',
#   'spiced rum',
#   'mango slice'],
#  ['brandy',
#   'preferably spanish',
#   'cherry liqueur',
#   'white or dark creme de cacao',
#   'egg white',
#   'freshly grated nutmeg'],
#  ['light rum',
#   'juice of a lemon',
#   'powdered sugar',
#   'egg white',
#   'sweet vermouth'],
#  ['cachaca',
#   'sweet vermouth',
#   'cynar',
#   'angostura bitters',
#   'grapefruit twist',
#   'flamed'],
#  ['gin', 'white creme de menthe', 'forbidden fruit'],
#  ['light rum',
#   'pineapple juice',
#   'fresh grapefruit juice',
#   'grenadine',
#   'pineapple wedge'],
#  ['creme de cassis', 'dry vermouth'],
#  ['gin', 'forbidden fruit', 'orange juice', 'lemon juice'],
#  ['strega', 'white creme de cacao', 'light cream'],
#  ['vodka', 'creme de cacao', 'light cream'],
#  ['gin', 'triple sec', 'anis'],
#  ['light rum', 'coffee-flavored brandy', 'half-and-half', '151-proof rum'],
#  ['juice of a lemon', 'powdered sugar', 'blended whiskey', 'egg white'],
#  ['fresh cherry tomatoes',
#   'dark rum',
#   'fresh lime juice',
#   'simple syrup',
#   'angostura bitters'],
#  ['juice of a lemon', 'powdered sugar', 'egg white', 'grenadine', 'gin'],
#  ['juice of a lemon', 'swedish punch', 'gin'],
#  ['juice of a lemon', 'brandy', 'triple sec', 'light rum'],
#  ['light rum', 'apple brandy', 'brandy', 'anisette'],
#  ['apple brandy', 'dubonnet'],
#  ['light rum',
#   'fresh lemon juice',
#   'fresh lime juice',
#   'pineapple juice',
#   'maraschino liqueur',
#   'lemon wheel'],
#  ['applejack', 'scotch', 'gin'],
#  ['white creme de cacao',
#   'vodka',
#   'galliano',
#   'grenadine',
#   'whipped cream and 3/4 oz'],
#  ['light rum', 'fresh lime juice', 'ginger ale'],
#  ['anisette', 'brandy', 'egg white'],
#  ['gin', 'egg white', 'orange bitters', 'grenadine'],
#  ['light rum', 'dubonnet', 'bitters'],
#  ['dark rum',
#   'fresh lime juice',
#   'maple syrup',
#   'brandy',
#   'yellow chartreuse'],
#  ['juice of orange', 'gin'],
#  ['orange juice', 'chilled champagne'],
#  ['light rum', 'sweet sherry', 'juice of a lime'],
#  ['dark rum', 'pineapple juice', 'ginger beer'],
#  ['juice of orange', 'egg white', 'dry vermouth', 'gin'],
#  ['gin', 'sweet vermouth', 'dry vermouth', 'orange'],
#  ['thin peeled fresh ginger',
#   'demerara syrup',
#   'fresh apple cider',
#   'light rum',
#   'jamaican ginger beer',
#   'green apple slice',
#   'lime wedge'],
#  ['apple brandy', 'brandy', 'fresh lemon juice', 'grenadine'],
#  ['dry sherry', 'light rum', 'sweet vermouth'],
#  ['17-year-old j. wray and nephew ltd. rum',
#   'coffee-flavored liqueur',
#   'egg white'],
#  ['brandy', 'white creme de cacao', 'benedictine'],
#  ['light rum', 'triple sec'],
#  ['light rum',
#   'apricot-flavored brandy',
#   'triple sec',
#   'lime juice',
#   'egg white'],
#  ['gin', 'apricot-flavored brandy', 'anisette', 'lemon juice'],
#  ['applejack', 'light rum', 'lime'],
#  ['light rum', 'dry vermouth', 'triple sec', 'fresh lime juice', 'grenadine'],
#  ['applejack', 'grenadine', 'orange juice', 'whole egg'],
#  ['whole egg', 'powdered sugar', 'brandy', 'light cream (if desired)'],
#  ['light rum', 'brandy', 'grenadine', 'triple sec', 'fresh lemon juice'],
#  ['light rum', 'fresh lime juice', 'grenadine'],
#  ['gin', 'dry vermouth'],
#  ['aged rhum agricole',
#   'dry sherry',
#   'aperol',
#   'angostura bitters',
#   'orange twist'],
#  ['light rum', 'fresh lime juice', 'simple syrup', 'grenadine'],
#  ['chilled stout', 'chilled champagne'],
#  ['dark rum',
#   'butterscotch schnapps',
#   'sweet vermouth',
#   'angostura bitters',
#   'edible flower',
#   'such as nasturtium'],
#  ['applejack', 'triple sec', 'lemon juice'],
#  ['egg white', 'juice of a lemon', 'powdered sugar', 'apple brandy'],
#  ['dubonnet', 'dry vermouth'],
#  ['apple brandy', 'triple sec', 'dubonnet'],
#  ['light rum',
#   'creole shrubb (rum-based orange liqueur)',
#   'ruby port',
#   'fresh lime juice',
#   'lime wheel'],
#  ['light or dark rum', 'water', 'simple syrup', 'brandy'],
#  ['brandy', 'apple brandy', 'triple sec', 'fresh lemon juice', 'dry vermouth'],
#  ['dry vermouth', 'gin', 'kummel'],
#  ['light or dark rum',
#   'fresh lime juice',
#   'simple syrup',
#   'angostura bitters',
#   'soda water'],
#  ['applejack', 'grapefruit juice'],
#  ['apricot-flavored brandy', 'triple sec', 'lemon juice'],
#  ['light rum', 'fresh lemon juice', 'simple syrup'],
#  ['light rum', 'lime juice', 'triple sec', 'sugar', 'egg white'],
#  ['anis', 'sugar'],
#  ['applejack', 'brandy', 'triple sec', 'chilled champagne'],
#  ['light rum', 'orange juice'],
#  ['light rum', 'fresh lime juice', 'soda water'],
#  ['old mr. boston creme de menthe (white)', 'desmond & duff scotch whisky'],
#  ['light rum',
#   'pineapple juice',
#   'grenadine',
#   'orange wheel',
#   'maraschino cherry'],
#  ['light rum',
#   '151-proof rum',
#   'simple syrup',
#   'angostura bitters',
#   'lemon twist'],
#  ['light rum', 'dry vermouth', 'lemon twist'],
#  ['light or dark rum', 'ginger ale or soda water', 'lemon twist'],
#  ['light rum', 'fresh lemon or lime juice', 'simple syrup'],
#  ['light rum',
#   'fresh lemon juice',
#   'simple syrup',
#   'grenadine',
#   'fresh seasonal fruit'],
#  ['armagnac',
#   'grand marnier',
#   'simple syrup',
#   'orange juice',
#   'chilled champagne',
#   'orange zest'],
#  ['light rum', 'simple syrup', 'soda water', 'orange and/or lemon zest'],
#  ['light rum',
#   'fresh lime juice',
#   'simple syrup',
#   'lemon wheel',
# ...
#  ['blanco tequila',
#   'falernum',
#   'simple syrup',
#   'fresh lime juice',
#   'lime wheel'],
#  ['reposado tequila',
#   'cherry heering',
#   'batavia arrack or light rum',
#   'fresh lime juice',
#   'ginger beer'],
#  ['blanco tequila',
#   'sweet vermouth',
#   'dry vermouth',
#   'campari',
#   'angostura bitters',
#   'lemon twist'],
#  ['old mr. boston rum',
#   'old mr. boston five star brandy',
#   'lemon juice',
#   'orange juice',
#   'grenadine'],
#  ['old mr. boston tequila',
#   'old mr. boston triple sec',
#   'lemon or lime juice'],
#  ['blanco tequila',
#   'aperol',
#   'fresh lime juice',
#   'grapefruit juice',
#   'agave nectar'],
#  ['dry vermouth', 'old thompson blended whiskey'],
#  ['juice of a lime', 'desmond & duff scotch whisky'],
#  ['blanco tequila',
#   'mezcal',
#   'creme de peche',
#   'guava puree',
#   'grapefruit juice',
#   'grapefruit twist'],
#  ['mr. boston creme de menthe', 'water'],
#  ['lime wedge',
#   'superfine sugar',
#   'blanco tequila',
#   'blue curacao',
#   'sloe gin',
#   'fresh lime juice',
#   'each fresh lemon juice',
#   'simple syrup',
#   '1 lime wheel'],
#  ['dark rum',
#   'triple sec',
#   'fresh lime juice',
#   'fresh lemon juice',
#   'simple syrup'],
#  ['orange peel', 'lump sugar', 'bitters'],
#  ['light rum', 'pineapple juice', 'maraschino liqueur', 'grenadine'],
#  ['brandy', 'sweet vermouth', 'angostura bitters'],
#  ['aged rhum agricole',
#   'amaretto',
#   'fresh lime juice',
#   'grapefruit juice',
#   'orgeat or almond syrup'],
#  ['light rum', 'brandy', 'fresh lemon juice', 'orange juice', 'grenadine'],
#  ['light rum', 'dark rum', 'fresh lemon juice', 'anisette', 'grenadine'],
#  ['old mr. boston kummel',
#   'old mr. boston dry gin',
#   'old mr. boston apricot flavored brandy',
#   'lemon juice'],
#  ['anisette', 'light rum', 'cream sherry', 'fresh lemon juice'],
#  ['dark rum',
#   'preferably jamaican',
#   'orange curacao',
#   'fresh lime juice (reserve 1/2 lime shell for garnish)',
#   'orgeat syrup',
#   'rock candy syrup or simple syrup',
#   'fresh mint sprig; pineapple wedge skewered with maraschino cherry'],
#  ['apple brandy', 'sweet vermouth', 'juice of a lime'],
#  ['fresh ginger',
#   'simple syrup',
#   'dark rum',
#   'vs cognac',
#   'each fresh lemon juice',
#   'angostura bitters',
#   'lemon twist'],
#  ['old mr. boston dry gin', 'claret', 'orange juice', 'jamaica rum'],
#  ['dark rum', 'amaretto', 'cola'],
#  ['apple brandy', 'pineapple juice', 'bitters'],
#  ['old mr. boston triple sec',
#   'absinthe substitute',
#   'maraschino',
#   'bitters',
#   'irish whiskey'],
#  ['151-proof rum', 'fresh lime juice', 'grenadine'],
#  ['light rum', 'sweet vermouth'],
#  ['light rum', 'gin', 'fresh lemon juice', 'triple sec'],
#  ['brandy',
#   'yellow chartreuse',
#   'fresh lemon juice',
#   'simple syrup',
#   'angostura bitters'],
#  ['juice of a lime',
#   'old mr. boston apricot flavored brandy',
#   'old mr. boston rum'],
#  ['aged rhum agricole',
#   'cold brewed coffee',
#   'allspice liqueur (pimento dram)',
#   'simple syrup',
#   'angostura bitters'],
#  ['spiced rum',
#   'mezcal',
#   'fresh lime juice',
#   'simple syrup',
#   'ground cinnamon'],
#  ['desmond & duff scotch whisky',
#   'dry vermouth',
#   'lemon juice',
#   'orange bitters'],
#  ['dark rum',
#   'coconut rum',
#   'ginger liqueur',
#   'mango nectar',
#   'cream of coconut',
#   'fresh lime juice',
#   'lime wheel'],
#  ['light rum',
#   'triple sec',
#   'fresh lemon juice',
#   'orange juice',
#   'raspberry syrup',
#   'small pineapple slice'],
#  ['old mr. boston 100 proof vodka',
#   'old mr. boston rock and rye',
#   'lemon juice'],
#  ['old mr. boston dry gin', 'old mr. boston anisette', 'absinthe substitute'],
#  ['light rum',
#   'dark rum',
#   'falernum',
#   'fresh lime juice',
#   'angostura bitters',
#   'ginger ale',
#   'lime wheel'],
#  ['juice of a lemon',
#   'old mr. boston kummel',
#   'old mr. boston green creme de menthe',
#   'old mr. boston dry gin',
#   'orange bitters'],
#  ['old mr. boston green creme de menthe',
#   'old mr. boston white creme de cacao',
#   'light sweet cream'],
#  ['light rum', 'melon liqueur', 'pineapple juice', 'grenadine'],
#  ['yellow chartreuse', 'old mr. boston apricot flavored brandy'],
#  ['light rum',
#   'fresh lime juice',
#   'green creme de menthe',
#   'triple sec',
#   'simple syrup scant',
#   'lime wheel'],
#  ['dark rum', 'triple sec', 'fresh lime juice', 'simple syrup'],
#  ['dark rum',
#   'madeira',
#   'simple syrup',
#   'egg',
#   'angostura bitters',
#   'freshly grated nutmeg'],
#  ['light rum',
#   'sweet vermouth',
#   'benedictine',
#   'fresh lemon juice',
#   'lemon twist'],
#  ['brandy', 'sweet vermouth', 'maraschino cherry'],
#  ['creme de violette',
#   'light rum',
#   'fresh lime juice',
#   'simple syrup',
#   'grapefruit bitters'],
#  ['each light rum',
#   'gin',
#   'vodka',
#   'blanco tequila',
#   'blue curacao',
#   'cherry-flavored brandy',
#   'simple syrup',
#   'fresh lemon juice',
#   'fresh orange juice',
#   'orange wheel'],
#  ["rose's lime juice", 'powdered sugar', 'old mr. boston dry gin'],
#  ['each dark rum',
#   'light rum',
#   'passion fruit syrup',
#   'lime juice',
#   'orange juice',
#   'each simple syrup',
#   'grenadine',
#   'orange half-wheel',
#   'maraschino cherry'],
#  ['light rum', 'apricot-flavored brandy', 'fresh lime juice'],
#  ['cachaca',
#   'fresh lime juice',
#   'honey syrup',
#   'angostura bitters',
#   'champagne or sparkling wine',
#   'mint sprig'],
#  ['dark rum',
#   'vanilla liqueur',
#   'simple syrup',
#   'creme fraiche',
#   'tiki bitters',
#   "such as bittermen's elemakule",
#   'freshly grated nutmeg'],
#  ['sweet vermouth', 'desmond & duff scotch whisky', 'bitters', 'sugar syrup'],
#  ['old mr. boston green creme de menthe',
#   'old mr. boston white creme de cacao',
#   'old mr. boston vodka'],
#  ['light rum', 'pineapple juice', 'fresh lemon juice'],
#  ['light rum',
#   'pineapple juice',
#   'cranberry juice',
#   'orange juice',
#   'lemon-lime soda'],
#  ['old mr. boston five star brandy',
#   'bitters',
#   'old mr. boston triple sec',
#   'powdered sugar'],
#  ['juice of a lime',
#   'old mr. boston dry gin',
#   'bitters',
#   'old mr. boston white creme de menthe'],
#  ['reposado tequila',
#   'dry vermouth',
#   'maraschino liqueur',
#   "peychaud's bitters",
#   'maraschino cherry'],
#  ['dark rum',
#   'fresh lime juice',
#   'pineapple juice',
#   'orange juice',
#   'maple syrup',
#   'angostura bitters'],
#  ['coffee-flavored brandy', 'triple sec', 'half-and-half'],
#  ['gin', 'dry vermouth', 'orange bitters'],
#  ['cucumber',
#   'blanco tequila',
#   'pineapple juice',
#   'fresh lemon juice',
#   'agave nectar',
#   'lemon-lime soda',
#   'cucumber slice'],
#  ['dark rum',
#   'yellow chartreuse',
#   'cherry heering',
#   'fresh lime juice',
#   'lime wheel'],
#  ['anejo tequila',
#   'aperol',
#   'sweet vermouth',
#   'peach bitters',
#   'grapefruit twist'],
#  ['blanco tequila', 'fresh white or ruby red grapefruit juice', 'soda water'],
#  ['light rum',
#   'sweet vermouth',
#   'amaretto',
#   'orange zest spiral',
#   'maraschino cherry'],
#  ['blanco tequila', 'grapefruit-flavored soda', 'lime wedge'],
#  ['lemon wheel',
#   'coarse salt',
#   'blanco tequila',
#   'blue curacao',
#   'simple syrup',
#   'fresh lemon juice',
#   'angostura bitters'],
#  ['dark rum',
#   'amaro',
#   'fresh lemon juice',
#   'orange bitters',
#   'sparkling apple cider',
#   'golden delicious apple wedge'],
#  ['dry vermouth', 'sweet vermouth', 'bitters', 'maraschino'],
#  ['anejo tequila',
#   'apple juice',
#   'fresh lemon juice',
#   'triple sec',
#   'simple syrup',
#   'angostura bitters',
#   'flamed lemon twist'],
#  ['light rum',
#   'fresh grapefruit juice',
#   'ginger liqueur',
#   'fresh lime juice',
#   'soda water'],
#  ['calvados', 'orange juice', 'triple sec', 'orange bitters'],
#  ['juice of a lime', 'powdered sugar', 'old mr. boston rum'],
#  ['reposado tequila',
#   'mezcal',
#   'agave nectar',
#   'angostura bitters',
#   'orange twist',
#   'flamed'],
#  ['pineapple juice',
#   'juice of a lime',
#   'old mr. boston rum',
#   'old mr. boston triple sec'],
#  ['light rum',
#   'fresh lemon juice',
#   'fresh lime juice',
#   'passion fruit syrup',
#   'maraschino cherry'],
#  ['blanco tequila',
#   'orange juice',
#   'blood orange juice',
#   'agave nectar',
#   'fresh lime juice',
#   'whiskey barrel bitters'],
#  ['old kentucky tavern bourbon whiskey', 'madeira', 'grenadine'],
#  ['reposado tequila',
#   'palo cortado or oloroso sherry',
#   'honey liqueur',
#   'orange bitters',
#   'lemon twist'],
#  ['light rum',
#   'brandy',
#   'gin',
#   'fresh lemon juice',
#   'each orange juice and sweet sherry',
#   'almond or orgeat syrup'],
#  ['blanco tequila', 'fresh lime juice'],
#  ['light rum',
#   'fresh lime juice',
#   'grapefruit juice',
#   'maraschino liqueur',
#   'simple syrup',
#   'lime wheel'],
#  ['reposado tequila',
#   'dry sherry',
#   'coffee liqueur',
#   'benedictine',
#   'lemon twist'],
#  ['light rum',
#   'fresh lime juice',
#   'sweet vermouth',
#   'white creme de cacao',
#   'grenadine',
#   'lime twist'],
#  ['blanco tequila',
#   'cranberry juice',
#   'orange juice',
#   'fresh lime juice',
#   'orange wheel'],
#  ['blackberry-flavored brandy', 'dry sherry', 'triple sec', 'half-and-half'],
#  ['juice of a lime', 'dubonnet', 'old mr. boston dry gin'],
#  ['light rum',
#   'fresh lime juice',
#   'simple syrup',
#   'grenadine',
#   'soda water (optional)',
#   'lemon half-wheel',
#   'maraschino cherry'],
#  ['dark rum',
#   'dubonnet rouge',
#   'benedictine',
#   'triple sec',
#   'orange twist',
#   'flamed'],
#  ['old mr. boston five star brandy',
#   'old mr. boston wild cherry flavored brandy',
#   'old mr. boston triple sec',
#   'grenadine',
#   'lemon juice'],
#  ['light rum', 'sweet vermouth', 'triple sec'],
#  ['juice of a lemon', 'old mr. boston triple sec', 'old mr. boston dry gin'],
#  ['blanco tequila',
#   'simple syrup',
#   'fresh lime juice',
#   'pomegranate molasses (available at middle eastern grocers)',
#   'angostura bitters',
#   'lime wheel'],
#  ['blanco tequila', 'fresh lemon juice', 'pineapple juice', 'grenadine'],
#  ['light rum', 'dry vermouth', 'angostura bitters'],
#  ['lime wedge',
#   'coarse salt',
#   'blanco tequila',
#   'cointreau triple sec',
#   'fresh lime juice'],
#  ['blanco tequila',
#   'each lillet blanc and lillet rouge',
#   'apple juice',
#   'fresh lime juice',
#   'agave nectar',
#   'blood orange wheel'],
#  ['lemon juice', 'old mr. boston triple sec', 'old mr. boston rum'],
#  ['blanco tequila',
#   'fresh grapefruit juice',
#   'fresh lime juice',
#   'yellow chartreuse',
#   'maraschino liqueur',
#   'grapefruit twist'],
#  ['reposado tequila', 'manzanilla sherry', 'pear liqueur'],
#  ['brandy',
#   'light rum',
#   'simple syrup',
#   'milk',
#   'freshly grated nutmeg',
#   'ground cinnamon'],
#  ['lime wedge',
#   'superfine sugar',
#   'gold tequila',
#   'triple sec',
#   'pineapple juice',
#   'orange juice',
#   'grenadine',
#   'lime wheel'],
#  ['blanco tequila',
#   'blood orange liqueur',
#   'becherovka (czech digestif)',
#   'fresh grapefruit juice',
#   'grapefruit twist',
#   'flamed'],
#  ['blanco tequila',
#   'aperol',
#   'dark creme de cacao',
#   'fresh lemon juice',
#   'grapefruit twist'],
#  ['lime wedge',
#   'coarse salt',
#   'blanco tequila',
#   'peppermint schnapps',
#   'grapefruit juice',
#   'simple syrup'],
#  ['campari',
#   'blanco tequila',
#   'fresh lime juice',
#   'honey syrup',
#   'angostura bitters'],
#  ['blanco tequila',
#   'vodka',
#   'triple sec',
#   'orange juice',
#   'fresh grenadine',
#   'lime wedge'],
#  ['blanco tequila', 'dry vermouth', 'benedictine'],
#  ['blanco tequila', 'white creme de cacao', 'heavy cream'],
#  ['blanco tequila',
#   'grapefruit juice',
#   'agave nectar',
#   'egg white',
#   'orange blossom water',
#   "peychaud's bitters"],
#  ['juice of a lemon', 'powdered sugar', 'old thompson blended whiskey'],
#  ['old mr. boston dry gin', 'bitters', 'dry vermouth', 'benedictine'],
#  ['brandy', 'hard cider', 'ginger ale'],
#  ['anejo tequila',
#   'honey liqueur',
#   'maraschino liqueur',
#   "the bitter truth's jerry thomas' own decanter bitters",
#   'dehydrated orange wheel'],
#  ['lime wedges',
#   'whole strawberry',
#   'simple syrup',
#   'blanco tequila',
#   'rose water'],
#  ['mezcal',
#   'palo cortado or oloroso sherry',
#   'allspice liqueur (pimento dram)',
#   'white creme de cacao'],
#  ['orange juice', 'champagne'],
#  ['reposado tequila',
#   'white curacao',
#   'olive brine',
#   'balsamic vinegar',
#   'fresh lime juice'],
#  ['blanco tequila', 'creme de cassis', 'fresh lime juice', 'lime wheel'],
#  ['blanco tequila',
#   'sweet vermouth',
#   'campari',
#   'grapefruit soda',
#   'rosemary sprig'],
#  ['whole strawberry',
#   'hulled',
#   'blanco tequila',
#   'campari',
#   'triple sec',
#   'fresh lemon juice',
#   'agave nectar',
#   'strawberry slice'],
#  ['blanco tequila',
#   'fresh grapefruit juice',
#   'fresh lime juice',
#   'campari',
#   'simple syrup',
#   'angostura bitters',
#   'lime wheel'],
#  ['anejo tequila',
#   'lillet rouge',
#   'orange curacao',
#   'orange bitters',
#   'orange twist'],
#  ['reposado tequila',
#   'orange juice',
#   'fresh lemon juice',
#   'grenadine',
#   'orange blossoms (optional): orange wedge'],
#  ['cherry-flavored brandy', 'gin', 'fresh lemon juice'],
#  ['old mr. boston five star brandy',
#   'old mr. boston rum',
#   'old mr. boston triple sec',
#   'juice of a lime'],
#  ['blanco tequila',
#   'peach schnapps',
#   'blue curacao',
#   'simple syrup',
#   'fresh lemon juice'],
#  ['anejo tequila',
#   'oloroso sherry',
#   'drambuie',
#   'rhubarb bitters',
#   'lemon twist'],
#  ['lime wedge coarse salt',
#   'blanco tequila',
#   'red wine',
#   'each triple sec',
#   'simple syrup',
#   'each fresh lemon juice',
#   'fresh lime juice',
#   'lemon-lime soda'],
#  ['old mr. boston rum', 'apple brandy', 'sweet vermouth'],
#  ['blanco tequila',
#   'triple sec',
#   'honey liqueur',
#   'fresh lime juice',
#   'fresh apple cider',
#   'lime wedge'],
#  ['blanco tequila', 'coffee liqueur', 'lemon twist'],
#  ['lime juice',
#   'coarse salt',
#   'blanco tequila',
#   'blue curacao',
#   'fresh lime juice'],
#  ['blanco tequila',
#   'tomato juice',
#   'fresh lemon juice',
#   'hot red pepper sauce',
#   'celery salt',
#   'lemon wheel'],
#  ['pineapple juice', 'juice of a lime', 'old mr. boston imported rum'],
#  ['blanco tequila',
#   'amaretto',
#   'pineapple juice',
#   'grenadine',
#   'maraschino cherry'],
#  ['old mr. boston dry gin', 'dry vermouth', 'juice of a blood orange'],
#  ['anejo tequila',
#   'agave nectar',
#   'angostura bitters',
#   'orange bitters',
#   'grapefruit twist'],
#  ['cucumber',
#   'fresh cilantro sprigs',
#   'blanco tequila',
#   'fresh lime juice',
#   'simple syrup',
#   'jalapeno hot pepper sauce',
#   'cucumber slice'],
#  ['cognac', 'sweet sherry', 'preferably pedro ximenez', 'egg yolk'],
#  ['old thompson blended whiskey', 'old mr. boston sloe gin'],
#  ['blanco tequila', 'orange juice', 'pineapple juice', 'lemon-lime soda'],
#  ['old mr. boston five star brandy',
#   'port',
#   'old mr. boston triple sec',
#   'old mr. boston dry gin'],
#  ['old mr. boston dry gin',
#   'old mr. boston apricot flavored brandy',
#   'grenadine'],
#  ['sake', 'gin', 'maraschino liqueur', 'unsprayed rose petal'],
#  ['gin', 'dry vermouth', 'blue curacao', 'angostura bitters'],
#  ['gin', 'cherry-flavored brandy', 'yellow chartreuse'],
#  ['gin', 'fresh lemon juice', 'maple syrup', 'orange bitters'],
#  ['gin', 'grapefruit juice', 'green chartreuse'],
#  ['old mr. boston dry gin',
#   'old mr. boston rum',
#   'old mr. boston creme de cacao',
#   'desmond & duff scotch whisky',
#   'sweet cream'],
#  ['fresh sage leaves',
#   'gin',
#   'fresh lime juice',
#   'limoncello',
#   'simple syrup',
#   'raspberries',
#   'lemon twist'],
#  ['absinthe', 'gin', 'triple sec', 'simple syrup', "peychaud's bitters"],
#  ['gin', 'dry vermouth', 'orange juice', 'triple sec'],
#  ['brandy', 'sweet vermouth', 'angostura bitters'],
#  ['gin', 'fresh lemon juice', 'triple sec', 'simple syrup'],
#  ['gin', 'triple sec'],
#  ['gin', 'dry vermouth', 'apricot-flavored brandy', 'fresh lemon juice'],
#  ['grenadine', 'juice of a lemon', 'swedish punch'],
#  ['gin', 'dry vermouth', 'apple brandy', 'apricot-flavored brandy'],
#  ['old mr. boston rum',
#   'sweet vermouth',
#   'apple flavored brandy',
#   'grenadine',
#   'lemon juice'],
#  ['gin',
#   'triple sec',
#   'creme de violette',
#   'fresh lemon juice',
#   'orange twist'],
#  ['lime wedge', 'superfine sugar', 'gin', 'triple sec', 'fresh lime juice'],
#  ['juice of orange',
#   'dry vermouth',
#   'sweet vermouth',
#   'old mr. boston dry gin'],
#  ['gin', 'dry vermouth', 'triple sec'],
#  ['gin', 'triple sec', 'pineapple juice'],
#  ['gin',
#   'grapefruit juice',
#   'fresh lime juice',
#   'yellow chartreuse',
#   'amaro',
#   'simple syrup']]

# %%
nametextvec = TextVectorization(
    max_tokens=20000,
    output_sequence_length=10,
    pad_to_max_tokens=True
)

description_vocab = list(recipe_df["description"])
name_vocab = list(recipe_inputs) + list(cocktail_inputs)
full_vocab = name_vocab + description_vocab

nametextvec.adapt(full_vocab)
name_voc = nametextvec.get_vocabulary()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_59388/2466021367.py in <module>
#       9 full_vocab = name_vocab + description_vocab
#      10
# ---> 11 nametextvec.adapt(full_vocab)
#      12 name_voc = nametextvec.get_vocabulary()
#
# x:\volundrai\cocktail-creator-ai\env\lib\site-packages\keras\engine\base_preprocessing_layer.py in adapt(self, data, batch_size, steps)
#     242       with data_handler.catch_stop_iteration():
#     243         for _ in data_handler.steps():
# --> 244           self._adapt_function(iterator)
#     245           if data_handler.should_sync:
#     246             context.async_wait()
#
# x:\volundrai\cocktail-creator-ai\env\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# x:\volundrai\cocktail-creator-ai\env\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     908
#     909       with OptionalXlaContext(self._jit_compile):
# --> 910         result = self._call(*args, **kwds)
#     911
#     912       new_tracing_count = self.experimental_get_tracing_count()
#
# x:\volundrai\cocktail-creator-ai\env\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     947       # In this case we have not created variables on the first call. So we can
#     948       # run the first trace but we should fail if variables are created.
# --> 949       results = self._stateful_fn(*args, **kwds)
#     950       if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     951         raise ValueError("Creating variables on a non-first call to a function"
#
# x:\volundrai\cocktail-creator-ai\env\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    3128       (graph_function,
#    3129        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3130     return graph_function._call_flat(
#    3131         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3132
#
# x:\volundrai\cocktail-creator-ai\env\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1957         and executing_eagerly):
#    1958       # No tape is watching; skip to running the function.
# -> 1959       return self._build_call_outputs(self._inference_function.call(
#    1960           ctx, args, cancellation_manager=cancellation_manager))
#    1961     forward_backward = self._select_forward_and_backward_functions(
#
# x:\volundrai\cocktail-creator-ai\env\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     596       with _InterpolateFunctionError(self):
#     597         if cancellation_manager is None:
# --> 598           outputs = execute.execute(
#     599               str(self.signature.name),
#     600               num_outputs=self._num_outputs,
#
# x:\volundrai\cocktail-creator-ai\env\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      56   try:
#      57     ctx.ensure_initialized()
# ---> 58     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      59                                         inputs, attrs, num_outputs)
#      60   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
ingtextvec = TextVectorization(
    max_tokens=15000,
    output_sequence_length=40,
    pad_to_max_tokens=True
)

vocab = list(recipe_outputs) + list(cocktail_outputs)

ingtextvec.adapt(vocab)
ing_voc = ingtextvec.get_vocabulary()

# %%
def create_embedding_matrix(voc):
    
    word_index = dict(zip(voc, range(len(voc))))
    path_to_glove_file = "glove.6B.300d.txt"

    embeddings_index = {}
    with open(path_to_glove_file, encoding="utf8") as f:
        for line in f:
            word, coefs = line.split(maxsplit=1)
            coefs = np.fromstring(coefs, "f", sep=" ")
            embeddings_index[word] = coefs

    num_tokens = len(voc) + 2
    embedding_dim = 300
    hits = 0
    misses = 0

    # Prepare embedding matrix
    embedding_matrix = np.zeros((num_tokens, embedding_dim))
    for word, i in word_index.items():
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None:
            # Words not found in embedding index will be all-zeros.
            # This includes the representation for "padding" and "OOV"
            embedding_matrix[i] = embedding_vector
            hits += 1
        else:
            misses += 1
    
    return embedding_matrix

# %%
encoder_inputs = Input(shape=(1,), dtype=tf.string)

e = nametextvec(encoder_inputs)

e = Embedding(
    num_tokens,
    embedding_dim,
    embeddings_initializer=tf.keras.initializers.Constant(embedding_matrix),
    trainable=False,
)(e)

_, encoder_h, encoder_c = LSTM(128, return_state=True)(e)

# %%
decoder_inputs = Input(shape=(1,), dtype=tf.string)

# %%
cocktail_df
# Out:
#                      name               category measurement-1  \
# 0                 Gauguin      Cocktail Classics          2 oz
# 1         Fort Lauderdale      Cocktail Classics      1 1/2 oz
# 2               Apple Pie  Cordials and Liqueurs          3 oz
# 3    Cuban Cocktail No. 1      Cocktail Classics        1/2 oz
# 4             Cool Carlos      Cocktail Classics      1 1/2 oz
# ..                    ...                    ...           ...
# 985  Wallis Blue Cocktail                    Gin             1
# 986    Minnehaha Cocktail      Cocktail Classics        1/4 oz
# 987      Wallick Cocktail                    Gin      1 1/2 oz
# 988   Waikiki Beachcomber                    Gin        3/4 oz
# 989        Vow Of Silence                    Gin      1 1/2 oz
#
#                     ingredient-1 measurement-2          ingredient-2  \
# 0                      Light Rum          1 oz   Passion Fruit Syrup
# 1                      Light Rum        1/2 oz        Sweet Vermouth
# 2                 Apple schnapps          1 oz     Cinnamon schnapps
# 3                Juice of a Lime        1/2 oz        Powdered Sugar
# 4                       Dark rum          2 oz       Cranberry Juice
# ..                           ...           ...                   ...
# 985  Lime wedge, superfine sugar          1 oz                   Gin
# 986              Juice of Orange        1/2 oz          Dry Vermouth
# 987                          Gin      1 1/2 oz          Dry Vermouth
# 988                          Gin        3/4 oz            Triple Sec
# 989                          Gin        3/4 oz      Grapefruit Juice
#
#     measurement-3       ingredient-3 measurement-4             ingredient-4  \
# 0            1 oz        Lemon Juice          1 oz               Lime Juice
# 1          1/4 oz    Juice of Orange        1/4 oz          Juice of a Lime
# 2             NaN        Apple slice           NaN                      NaN
# 3            2 oz          Light Rum           NaN                      NaN
# 4            2 oz    Pineapple Juice          1 oz           Orange curacao
# ..            ...                ...           ...                      ...
# 985          1 oz         Triple Sec          1 oz         Fresh Lime Juice
# 986        1/2 oz     Sweet Vermouth          1 oz   Old Mr. Boston Dry Gin
# 987          1 oz         Triple Sec           NaN                      NaN
# 988        1/2 oz    Pineapple Juice           NaN                      NaN
# 989        1/2 oz   Fresh Lime Juice        1/2 oz        Yellow Chartreuse
#
#     measurement-5 ingredient-5 measurement-6   ingredient-6  \
# 0             NaN          NaN           NaN            NaN
# 1             NaN          NaN           NaN            NaN
# 2             NaN          NaN           NaN            NaN
# 3             NaN          NaN           NaN            NaN
# 4            1 oz     Sour Mix           NaN            NaN
# ..            ...          ...           ...            ...
# 985           NaN          NaN           NaN            NaN
# 986           NaN          NaN           NaN            NaN
# 987           NaN          NaN           NaN            NaN
# 988           NaN          NaN           NaN            NaN
# 989        1/4 oz        Amaro        1/4 oz   Simple Syrup
#
#                                           instructions                glass  \
# 0    Combine ingredients with a cup of crushed ice ...  Old-Fashioned Glass
# 1    Shake with ice and strain into old-fashioned g...  Old-Fashioned Glass
# 2    Pour into ice-filled old-fashioned glass. Garn...  Old-Fashioned Glass
# 3      Shake with ice and  strain into cocktail glass.       Cocktail Glass
# 4    Mix all ingredients except curacao with ice, s...        Collins Glass
# ..                                                 ...                  ...
# 985  Rim old-fashioned glass with lime and sugar. F...  Old-Fashioned Glass
# 986  Shake well with cracked ice and strain into 4 ...       Cocktail Glass
# 987  Stir with ice and strain into chilled cocktail...       Cocktail Glass
# 988  Shake with ice and strain into chilled cocktai...       Cocktail Glass
# 989  Shake with ice and strain into chilled cocktai...       Cocktail Glass
#
#            glass-size
# 0       6 to 8 ounces
# 1       6 to 8 ounces
# 2       6 to 8 ounces
# 3    6 or more ounces
# 4     14 to 16 ounces
# ..                ...
# 985     6 to 8 ounces
# 986  6 or more ounces
# 987  6 or more ounces
# 988  6 or more ounces
# 989  6 or more ounces
#
# [990 rows x 17 columns]
